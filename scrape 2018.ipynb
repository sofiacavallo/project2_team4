# %%
# Declare Dependencies 
from splinter import Browser
from bs4 import BeautifulSoup
from flask import request
import html5lib
import pandas as pd
import lxml
import requests
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
import requests as rq
import re
import time 
import random

# %%
# Choose the executable path to driver 
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
a = [1,2,3]
a.extend([4,5])
a
# Out:
# [1, 2, 3, 4, 5]

# %%
# URL
result = []
list_rows = []
#rows = []
for i in range(0, 17):
    base_url = f'https://www.gunviolencearchive.org/reports/total-number-of-incidents?page={i}&year=2018'
    r = rq.get(base_url)
    time.sleep(random.randint(1,5))
    
    soup = BeautifulSoup(r.text, 'html.parser')
    table_rows = soup.find_all('tr')
    #print('Number of results', len(table_rows))
    for tr in table_rows:
        row_td = tr.find_all('td')
    rows =soup.findAll('tr')
    row = [row.get_text().strip('\n') for row in rows]
    str_cells = str(row_td)
    cleantext = BeautifulSoup(str_cells, "lxml").get_text()
    rows =soup.findAll('tr')
    for row in rows:
        cells = row.find_all('td')
        str_cells = str(cells)
        clean = re.compile('<.*?>')
        clean2 = (re.sub(clean, '',str_cells))
        list_rows.append(clean2)

df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1  [1290435, December 31, 2018, Nebraska, Omaha, ...
# 2  [1291253, December 31, 2018, West Virginia, Wo...
# 3  [1289028, December 31, 2018, Oklahoma, Oklahom...
# 4  [1290413, December 31, 2018, Nevada, Las Vegas...
# 5  [1290400, December 31, 2018, Vermont, Burlingt...
# 6  [1295009, December 31, 2018, Missouri, Saint L...
# 7  [1291926, December 31, 2018, North Carolina, D...
# 8  [1290378, December 31, 2018, Massachusetts, Wo...
# 9  [1290368, December 31, 2018, Texas, Houston, K...

# %%
df
# Out:
#                                                      0
# 0                                                   []
# 1    [1290435, December 31, 2018, Nebraska, Omaha, ...
# 2    [1291253, December 31, 2018, West Virginia, Wo...
# 3    [1289028, December 31, 2018, Oklahoma, Oklahom...
# 4    [1290413, December 31, 2018, Nevada, Las Vegas...
# 5    [1290400, December 31, 2018, Vermont, Burlingt...
# 6    [1295009, December 31, 2018, Missouri, Saint L...
# 7    [1291926, December 31, 2018, North Carolina, D...
# 8    [1290378, December 31, 2018, Massachusetts, Wo...
# 9    [1290368, December 31, 2018, Texas, Houston, K...
# 10   [1290364, December 31, 2018, Massachusetts, Bo...
# 11   [1289364, December 31, 2018, Indiana, Evansvil...
# 12   [1289362, December 31, 2018, New York, New Yor...
# 13   [1292848, December 31, 2018, Kansas, Olathe, 1...
# 14   [1289794, December 31, 2018, Georgia, Stone Mo...
# 15   [1291834, December 31, 2018, Florida, Fort Pie...
# 16   [1290146, December 31, 2018, Texas, Fort Worth...
# 17   [1290313, December 31, 2018, Kansas, Goessel, ...
# 18   [1288927, December 31, 2018, Colorado, Longmon...
# 19   [1291156, December 31, 2018, Texas, Mexia, 500...
# 20   [1290298, December 31, 2018, Ohio, Dayton, 250...
# 21   [1289318, December 31, 2018, Massachusetts, Me...
# 22   [1290261, December 31, 2018, Kentucky, Owensbo...
# 23   [1290285, December 31, 2018, Texas, Houston, 1...
# 24   [1290274, December 31, 2018, Kansas, Topeka, S...
# 25   [1290266, December 31, 2018, Louisiana, Baton ...
# 26                                                  []
# 27   [1288883, December 31, 2018, Pennsylvania, Wat...
# 28   [1289893, December 31, 2018, South Carolina, C...
# 29   [1290256, December 31, 2018, Texas, Fort Worth...
# ..                                                 ...
# 412  [1287659, December 29, 2018, North Carolina, C...
# 14            Stone Mountain                     5345 Memorial Dr     1     0
# 15               Fort Pierce              2400 block of N 42nd St     0     0
# 16                Fort Worth                      5430 Miller Ave     0     0
# 17                   Goessel                  301 E Commercial St     0     0
# 18                  Longmont                        2211 Pratt St     1     0
# 19                     Mexia           500 block of W Commerce St     0     0
# 20                    Dayton               2500 block of Home Ave     0     1
# 21                   Methuen            Lowell St and N Lowell St     0     0
# 22                 Owensboro                  700 block of Elm St     0     0
# 23                   Houston                     12101 Fondren Rd     1     0
# 24                    Topeka        SW 17th St and SW Westport Dr     0     0
# 25               Baton Rouge            6300 block of Airline Hwy     0     0
# 26                      None                                 None  None  None
# 27                Waterville                            Church St     1     0
# 28                  Columbia    300 block of S Highland Forest Dr     1     0
# 29                Fort Worth                  2900 Renaissance Dr     0     1
# ..                       ...                                  ...   ...   ...
# 412                Charlotte                         Columbus Cir     0     2
# 413             Kernersville                    I-40BUS and NC 66     0     0
# 414                   Urbana              2000 block of Vawter St     1     0
# 415               Washington                  50 block of O St NW     0     0
# 416                     None                                 None  None  None
# 417                  Gadsden            1300 block of Chestnut St     0     0
# 418               Montgomery          4400 block of Richardson Rd     0     1
# 419                 Columbus                     826 Wedgewood Dr     1     0
# 420                   Dayton             800 block of Huffman Ave     0     1
# 421              Bourbonnais                       1887 Armour Rd     0     1
# 422                   Revere                       16 Pleasant St     0     1
# 423                   Aurora              12051 E Mississippi Ave     1     0
# 424               Orangeburg           500 block of Shadowlawn Dr     0     0
# 425                 Kankakee          400 block of S Wildwood Ave     0     1
# 426                 Savannah                Treat Ave and Iowa St     1     0
# 427        North Little Rock               2900 block of Pike Ave     2     0
# 428                     Bend            Fontana Rd and Stellar Dr     0     0
# 429                  Atlanta                       1975 North Ave     0     1
# 430          Charlottesville             300 block of 6 1/2 St SW     0     0
# 431              Victorville                    11600 Amargosa Rd     0     0
# 432              Little Rock                        2027 Bond Ave     0     2
# 433             Mount Juliet                       100 Carrick Ct     0     0
# 434                   Athens                      402 McKinley Dr     0     0
# 435                Fairfield                            Oliver Rd     0     1
# 436                  Meriden                            E Main St     0     0
# 437                   Oxnard            300 block of Campbell Way     0     1
# 438                   Oxnard             1200 block of North H St     0     1
# 439                   Durham               3300 block of Guess Rd     0     1
# 440                   Auburn              100 block of Diamond St     0     0
# 441                 Anderson              2700 block of Barney Rd     0     0
#
#                                   8
# 0                              None
# 1     View Incident\nView Source\n]
# 2     View Incident\nView Source\n]
# 3     View Incident\nView Source\n]
# 4     View Incident\nView Source\n]
# 5     View Incident\nView Source\n]
# 6     View Incident\nView Source\n]
# 7     View Incident\nView Source\n]
# 8     View Incident\nView Source\n]
# 9     View Incident\nView Source\n]
# 10    View Incident\nView Source\n]
# 11    View Incident\nView Source\n]
# 12    View Incident\nView Source\n]
# 13    View Incident\nView Source\n]
# 14    View Incident\nView Source\n]
# 15    View Incident\nView Source\n]
# 16    View Incident\nView Source\n]
# 17    View Incident\nView Source\n]
# 18    View Incident\nView Source\n]
# 19    View Incident\nView Source\n]
# 20    View Incident\nView Source\n]
# 21    View Incident\nView Source\n]
# 22    View Incident\nView Source\n]
# 23    View Incident\nView Source\n]
# 24    View Incident\nView Source\n]
# 25    View Incident\nView Source\n]
# 26                             None
# 27    View Incident\nView Source\n]
# 28    View Incident\nView Source\n]
# 29    View Incident\nView Source\n]
# ..                              ...
# 412   View Incident\nView Source\n]
# 413   View Incident\nView Source\n]
# 414   View Incident\nView Source\n]
# 415   View Incident\nView Source\n]
# 416                            None
# 417   View Incident\nView Source\n]
# 418   View Incident\nView Source\n]
# 419   View Incident\nView Source\n]
# 420   View Incident\nView Source\n]
# 421   View Incident\nView Source\n]
# 422   View Incident\nView Source\n]
# 423   View Incident\nView Source\n]
# 424   View Incident\nView Source\n]
# 425   View Incident\nView Source\n]
# 426   View Incident\nView Source\n]
# 427   View Incident\nView Source\n]
# 428   View Incident\nView Source\n]
# 429   View Incident\nView Source\n]
# 430   View Incident\nView Source\n]
# 431   View Incident\nView Source\n]
# 432   View Incident\nView Source\n]
# 433   View Incident\nView Source\n]
# 434   View Incident\nView Source\n]
# 435   View Incident\nView Source\n]
# 436   View Incident\nView Source\n]
# 437   View Incident\nView Source\n]
# 438   View Incident\nView Source\n]
# 439   View Incident\nView Source\n]
# 440   View Incident\nView Source\n]
# 441   View Incident\nView Source\n]
#
# [442 rows x 9 columns]

# %%
headers = rows[0].find_all('th')
headers = [header.get_text().strip('\n') for header in headers]
headers
# Out:
# ['Incident ID',
#  'Incident Date',
#  'State',
#  'City Or County',
#  'Address',
#  '# Killed',
#  '# Injured',
#  'Operations']

# %%
all_header = []
col_str = str(headers)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ["['Incident ID', 'Incident Date', 'State', 'City Or County', 'Address', '# Killed', '# Injured', 'Operations']"]

# %%
header = all_header[0].replace('[', '').replace(']', '').split(',')[:8]
header.insert(2, 'year')
# new_header = []
# for item in header:
#     new_header.append(item.strip())
header = [name.replace('"', '').replace("'", "").replace('#', '').strip() for name in header]
header
# Out:
# ['Incident ID',
#  'Incident Date',
#  'year',
#  'State',
#  'City Or County',
#  'Address',
#  'Killed',
#  'Injured',
#  'Operations']

# %%
header_df = pd.DataFrame(header).T
header_df.head()
# Out:
#              0              1     2      3               4        5       6  \
# 0  Incident ID  Incident Date  year  State  City Or County  Address  Killed
#
#          7           8
# 0  Injured  Operations

# %%
df.shape, header_df.shape
# Out:
# ((442, 9), (1, 9))

# %%
frames = [header_df, df]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#              0              1      2                3  \
# 0  Incident ID  Incident Date   year            State
# 0            ]           None   None             None
# 1      1290435    December 31   2018         Nebraska
# 2      1291253    December 31   2018    West Virginia
# 3      1289028    December 31   2018         Oklahoma
# 4      1290413    December 31   2018           Nevada
# 5      1290400    December 31   2018          Vermont
# 6      1295009    December 31   2018         Missouri
# 7      1291926    December 31   2018   North Carolina
# 8      1290378    December 31   2018    Massachusetts
#
#                          4                                    5       6  \
# 0           City Or County                              Address  Killed
# 0                     None                                 None    None
# 1                    Omaha               2500 block of Emmet St       0
# 2              Worthington                      Michael Hill Rd       0
# 3            Oklahoma City   N Rockwell Ave and W Wilshire Blvd       0
# 4                Las Vegas             N E St and Jefferson Ave       0
# 5               Burlington      N Champlain St and Manhattan Dr       0
# 6   Saint Louis (Overland)                                  N/A       0
# 7                   Durham                              Hill St       0
# 8                Worcester          Dorchester St and Cutler St       0
#
#          7                               8
# 0  Injured                      Operations
# 0     None                            None
# 1        0   View Incident\nView Source\n]
# 2        0   View Incident\nView Source\n]
# 3        1   View Incident\nView Source\n]
# 4        1   View Incident\nView Source\n]
# 5        0   View Incident\nView Source\n]
# 6        0   View Incident\nView Source\n]
# 7        1   View Incident\nView Source\n]
# 8        0   View Incident\nView Source\n]

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#    Incident ID  Incident Date   year           State  City Or County  \
# 0  Incident ID  Incident Date   year           State  City Or County
# 0            ]           None   None            None            None
# 1      1290435    December 31   2018        Nebraska           Omaha
# 2      1291253    December 31   2018   West Virginia     Worthington
# 3      1289028    December 31   2018        Oklahoma   Oklahoma City
#
#                                Address  Killed  Injured  \
# 0                              Address  Killed  Injured
# 0                                 None    None     None
# 1               2500 block of Emmet St       0        0
# 2                      Michael Hill Rd       0        0
# 3   N Rockwell Ave and W Wilshire Blvd       0        1
#
#                        Operations
# 0                      Operations
# 0                            None
# 1   View Incident\nView Source\n]
# 2   View Incident\nView Source\n]
# 3   View Incident\nView Source\n]

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 0 to 441
# Data columns (total 9 columns):
# Incident ID       443 non-null object
# Incident Date     426 non-null object
# year              426 non-null object
# State             426 non-null object
# City Or County    426 non-null object
# Address           426 non-null object
# Killed            426 non-null object
# Injured           426 non-null object
# Operations        426 non-null object
# dtypes: object(9)
# memory usage: 34.6+ KB
# (443, 9)

# %%
df6 = df5.dropna(axis=0, how='any')

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   Incident ID Incident Date   year           State  City Or County  \
# 1     1290435   December 31   2018        Nebraska           Omaha
# 2     1291253   December 31   2018   West Virginia     Worthington
# 3     1289028   December 31   2018        Oklahoma   Oklahoma City
# 4     1290413   December 31   2018          Nevada       Las Vegas
# 5     1290400   December 31   2018         Vermont      Burlington
#
#                                Address Killed Injured  \
# 1               2500 block of Emmet St      0       0
# 2                      Michael Hill Rd      0       0
# 3   N Rockwell Ave and W Wilshire Blvd      0       1
# 4             N E St and Jefferson Ave      0       1
# 5      N Champlain St and Manhattan Dr      0       0
#
#                        Operations
# 1   View Incident\nView Source\n]
# 2   View Incident\nView Source\n]
# 3   View Incident\nView Source\n]
# 4   View Incident\nView Source\n]
# 5   View Incident\nView Source\n]

# %%
df7['Operations'] = df7['Operations'].str.strip(']').str.strip('\n')
df7.head()
# Out:
#   Incident ID Incident Date   year           State  City Or County  \
# 1     1290435   December 31   2018        Nebraska           Omaha
# 2     1291253   December 31   2018   West Virginia     Worthington
# 3     1289028   December 31   2018        Oklahoma   Oklahoma City
# 4     1290413   December 31   2018          Nevada       Las Vegas
# 5     1290400   December 31   2018         Vermont      Burlington
#
#                                Address Killed Injured  \
# 1               2500 block of Emmet St      0       0
# 2                      Michael Hill Rd      0       0
# 3   N Rockwell Ave and W Wilshire Blvd      0       1
# 4             N E St and Jefferson Ave      0       1
# 5      N Champlain St and Manhattan Dr      0       0
#
#                     Operations
# 1   View Incident\nView Source
# 2   View Incident\nView Source
# 3   View Incident\nView Source
# 4   View Incident\nView Source
# 5   View Incident\nView Source

# %%
df7 = df7.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df7.to_csv("gunviolence2018_db.csv")

# %%
# Create engine using the `gunviolence_db.sqlite` database file
#engine = create_engine("sqlite:///../project2_team4/gunviolence_db.sqlite")

# %%
#df7.to_sql("gunviolence_db", con=engine)

# %%
#from geopy.geocoders import Nominatim
#from geopy import geocoders
#from geopy.exc import GeocoderTimedOut

# %%
#geolocator = Nominatim(user_agent="gunviolence_2018")
#g = geocoders.GoogleV3(api_key='AIzaSyAkBEmk1KIJqs-0NObr_lr1fxdA6l1grw8')
#def transfer_adress(Address: str):
#    location = g.geocode(address, timeout=10)
#    return (location.latitude, location.longitude)

# %%
#for i in df7.index: 
#     print(df7['Address'][i])

# %%
#df7['lat, lon'] = df7['Address'].apply(transfer_adress_to_cordinates)
#df7.head()

# %%
#print((location.latitude, location.longitude))
