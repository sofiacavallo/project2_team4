# %%
# Declare Dependencies 
from splinter import Browser
from bs4 import BeautifulSoup
from flask import request
import html5lib
import pandas as pd
import lxml
import requests
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
import requests as rq
import re
import time 
import random

# %%
# Choose the executable path to driver 
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL
result = []
list_rows = []
#rows = []
for i in range(0, 17):
    base_url = f'https://www.gunviolencearchive.org/reports/total-number-of-incidents?page={i}&year=2015'
    r = rq.get(base_url)
    time.sleep(random.randint(1,5))
    
    soup = BeautifulSoup(r.text, 'html.parser')
    table_rows = soup.find_all('tr')
    #print('Number of results', len(table_rows))
    for tr in table_rows:
        row_td = tr.find_all('td')
    rows =soup.findAll('tr')
    row = [row.get_text().strip('\n') for row in rows]
    str_cells = str(row_td)
    cleantext = BeautifulSoup(str_cells, "lxml").get_text()
    rows =soup.findAll('tr')
    for row in rows:
        cells = row.find_all('td')
        str_cells = str(cells)
        clean = re.compile('<.*?>')
        clean2 = (re.sub(clean, '',str_cells))
        list_rows.append(clean2)

df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1  [480589, December 31, 2015, New York, New York...
# 2  [476987, December 31, 2015, North Carolina, Du...
# 3  [476984, December 31, 2015, Missouri, Kansas C...
# 4  [476351, December 31, 2015, Massachusetts, New...
# 5  [476966, December 31, 2015, North Carolina, Ch...
# 6  [476499, December 31, 2015, Tennessee, Chattan...
# 7  [483306, December 31, 2015, Missouri, Kansas C...
# 8  [484916, December 31, 2015, Kansas, Salina, 40...
# 9  [484914, December 31, 2015, Kansas, Salina, Un...

# %%
df
# Out:
#                                                      0
# 0                                                   []
# 1    [480589, December 31, 2015, New York, New York...
# 2    [476987, December 31, 2015, North Carolina, Du...
# 3    [476984, December 31, 2015, Missouri, Kansas C...
# 4    [476351, December 31, 2015, Massachusetts, New...
# 5    [476966, December 31, 2015, North Carolina, Ch...
# 6    [476499, December 31, 2015, Tennessee, Chattan...
# 7    [483306, December 31, 2015, Missouri, Kansas C...
# 8    [484916, December 31, 2015, Kansas, Salina, 40...
# 9    [484914, December 31, 2015, Kansas, Salina, Un...
# 10   [477545, December 31, 2015, North Carolina, Pa...
# 11   [476299, December 31, 2015, Pennsylvania, Phil...
# 12   [478675, December 31, 2015, California, Modest...
# 13   [476809, December 31, 2015, Washington, Woodla...
# 14   [476886, December 31, 2015, Iowa, Des Moines, ...
# 15   [476880, December 31, 2015, Florida, Bradenton...
# 16   [476872, December 31, 2015, Indiana, Merrillvi...
# 17   [478620, December 31, 2015, Louisiana, New Orl...
# 18   [477490, December 31, 2015, North Carolina, Ga...
# 19   [476265, December 31, 2015, Texas, Arlington, ...
# 20   [476148, December 31, 2015, Tennessee, Madison...
# 21   [476256, December 31, 2015, Maryland, Oakland,...
# 22   [481799, December 31, 2015, Texas, Montgomery ...
# 23   [476509, December 31, 2015, Illinois, Chicago ...
# 24   [476760, December 31, 2015, Maryland, Halethor...
# 25   [477473, December 31, 2015, Ohio, Cleveland, 3...
# 26                                                  []
# 27   [476040, December 31, 2015, Pennsylvania, Phil...
# 28   [476814, December 31, 2015, Florida, Palm Beac...
# 29   [476807, December 31, 2015, California, San Fr...
# ..                                                 ...
# 412  [477719, December 29, 2015, South Carolina, La...
# 413  [475866, December 29, 2015, Michigan, Davisbur...
# 414  [475134, December 29, 2015, Oklahoma, Yukon, Y...
# 415  [475847, December 29, 2015, Oklahoma, Guthrie,...
# 423                       Philadelphia
# 424                        San Antonio
# 425                            Memphis
# 426                        Kansas City
# 427                        San Antonio
# 428                              Flint
# 429                            Greeley
# 430                           Columbia
# 431                            Jackson
# 432                          Lancaster
# 433                             Toledo
# 434                            Reserve
# 435                        New Orleans
# 436                               Orem
# 437                            Memphis
# 438                            Spokane
# 439                          Cleveland
# 440                 Dinwiddie (county)
# 441                      Sturgeon Lake
#
#                                                5     6     7  \
# 0                                           None  None  None
# 1                                 Sherman Street     0     1
# 2                               433 Pilot Street     0     2
# 3           E. 37th Street and Blue Ridge Cutoff     0     0
# 4                                Pleasant Street     1     0
# 5                                 Westpark Drive     0     2
# 6                          2700 block 6th Avenue     0     1
# 7                  3000 block of Woodland Avenue     0     1
# 8                    400 block of S. 12th Street     0     0
# 9           University Place and Phillips Street     0     0
# 10                                   Sawyer Road     1     0
# 11                4400 block of North 7th Street     0     2
# 12                                           N/A     0     0
# 13                               143 Whalen Road     1     0
# 14                  1300 block of E. 14th Street     0     1
# 15                 500 block of 13th Avenue West     0     0
# 16                    5500 block of Hayes Street     0     3
# 17                                           N/A     0     0
# 18                               Highland Street     0     1
# 19                            1300 S. Bowen Road     0     1
# 20    1700 block of Cumberland Station Boulevard     0     1
# 21                               Garrett Highway     0     0
# 22         Kendal Ridge Lane and Clear Oaks Lane     0     0
# 23           7200 block of South Aberdeen Street     0     1
# 24                       400 block of Fourth Ave     0     1
# 25               3800 block of East 144th Street     0     0
# 26                                          None  None  None
# 27                      7100 block of Erdrick St     0     1
# 28                             Pipers Clay Drive     0     1
# 29                             Fillmore and Turk     0     1
# ..                                           ...   ...   ...
# 412                                  Miami Drive     0     1
# 413                   10000 block of Puffer Road     0     0
# 414        Yukon Parkway and Ranchwood Boulevard     0     0
# 415                               N. Pine Street     0     0
# 416                                         None  None  None
# 417                             112 Planters Way     1     0
# 418                 1400 block of Hagerman Drive     0     1
# 419                                   3427 Jorns     1     0
# 420                                  10th Street     1     0
# 421                             1029 Park Avenue     0     1
# 422                           Fine Wright Avenue     0     1
# 423                               51st and Brown     0     1
# 424                     4611 East Houston Street     0     1
# 425             6000 block of Water Stone Oakway     1     0
# 426      Bannister Road and Blue Ridge Boulevard     0     1
# 427                   100 block of Charing Cross     0     0
# 428          3000 block of North Franklin Avenue     0     1
# 429                    2500 block of 23rd Avenue     0     0
# 430               1400 block of Greensboro Drive     0     0
# 431                 100 block of Rockwell Street     0     1
# 432               Carmel Road and Belmont Circle     0     1
# 433                             West Park Street     0     1
# 434         600 block of Northwest Second Street     0     2
# 435                            7001 Martin Drive     2     0
# 436                            1757 Village Lane     2     0
# 437                 6800 block of Birch Run Lane     0     1
# 438               Highway 195 and Excelsior Road     0     1
# 439           East 131st Street and Union Avenue     0     0
# 440                    6100 block of Duncan Road     0     1
# 441                                          N/A     0     0
#
#                                   8
# 0                              None
# 1     View Incident\nView Source\n]
# 2     View Incident\nView Source\n]
# 3     View Incident\nView Source\n]
# 4     View Incident\nView Source\n]
# 5     View Incident\nView Source\n]
# 6     View Incident\nView Source\n]
# 7     View Incident\nView Source\n]
# 8     View Incident\nView Source\n]
# 9     View Incident\nView Source\n]
# 10    View Incident\nView Source\n]
# 11    View Incident\nView Source\n]
# 12    View Incident\nView Source\n]
# 13    View Incident\nView Source\n]
# 14    View Incident\nView Source\n]
# 15    View Incident\nView Source\n]
# 16    View Incident\nView Source\n]
# 17    View Incident\nView Source\n]
# 18    View Incident\nView Source\n]
# 19    View Incident\nView Source\n]
# 20    View Incident\nView Source\n]
# 21    View Incident\nView Source\n]
# 22    View Incident\nView Source\n]
# 23    View Incident\nView Source\n]
# 24    View Incident\nView Source\n]
# 25    View Incident\nView Source\n]
# 26                             None
# 27    View Incident\nView Source\n]
# 28    View Incident\nView Source\n]
# 29    View Incident\nView Source\n]
# ..                              ...
# 412   View Incident\nView Source\n]
# 413   View Incident\nView Source\n]
# 414   View Incident\nView Source\n]
# 415   View Incident\nView Source\n]
# 416                            None
# 417   View Incident\nView Source\n]
# 418   View Incident\nView Source\n]
# 419   View Incident\nView Source\n]
# 420   View Incident\nView Source\n]
# 421   View Incident\nView Source\n]
# 422   View Incident\nView Source\n]
# 423   View Incident\nView Source\n]
# 424   View Incident\nView Source\n]
# 425   View Incident\nView Source\n]
# 426   View Incident\nView Source\n]
# 427   View Incident\nView Source\n]
# 428   View Incident\nView Source\n]
# 429   View Incident\nView Source\n]
# 430   View Incident\nView Source\n]
# 431   View Incident\nView Source\n]
# 432   View Incident\nView Source\n]
# 433   View Incident\nView Source\n]
# 434   View Incident\nView Source\n]
# 435   View Incident\nView Source\n]
# 436   View Incident\nView Source\n]
# 437   View Incident\nView Source\n]
# 438   View Incident\nView Source\n]
# 439   View Incident\nView Source\n]
# 440   View Incident\nView Source\n]
# 441   View Incident\nView Source\n]
#
# [442 rows x 9 columns]

# %%
headers = rows[0].find_all('th')
headers = [header.get_text().strip('\n') for header in headers]
headers
# Out:
# ['Incident ID',
#  'Incident Date',
#  'State',
#  'City Or County',
#  'Address',
#  '# Killed',
#  '# Injured',
#  'Operations']

# %%
all_header = []
col_str = str(headers)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ["['Incident ID', 'Incident Date', 'State', 'City Or County', 'Address', '# Killed', '# Injured', 'Operations']"]

# %%
header = all_header[0].replace('[', '').replace(']', '').split(',')[:8]
header.insert(2, 'year')
# new_header = []
# for item in header:
#     new_header.append(item.strip())
header = [name.replace('"', '').replace("'", "").replace('#', '').strip() for name in header]
header
# Out:
# ['Incident ID',
#  'Incident Date',
#  'year',
#  'State',
#  'City Or County',
#  'Address',
#  'Killed',
#  'Injured',
#  'Operations']

# %%
header_df = pd.DataFrame(header).T
header_df.head()
# Out:
#              0              1     2      3               4        5       6  \
# 0  Incident ID  Incident Date  year  State  City Or County  Address  Killed
#
#          7           8
# 0  Injured  Operations

# %%
df.shape, header_df.shape
# Out:
# ((442, 9), (1, 9))

# %%
frames = [header_df, df]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#              0              1      2                3                      4  \
# 0  Incident ID  Incident Date   year            State         City Or County
# 0            ]           None   None             None                   None
# 1       480589    December 31   2015         New York   New York (Manhattan)
# 2       476987    December 31   2015   North Carolina                 Durham
# 3       476984    December 31   2015         Missouri            Kansas City
# 4       476351    December 31   2015    Massachusetts            New Bedford
# 5       476966    December 31   2015   North Carolina              Charlotte
# 6       476499    December 31   2015        Tennessee            Chattanooga
# 7       483306    December 31   2015         Missouri            Kansas City
# 8       484916    December 31   2015           Kansas                 Salina
#
#                                        5       6        7  \
# 0                                Address  Killed  Injured
# 0                                   None    None     None
# 1                         Sherman Street       0        1
# 2                       433 Pilot Street       0        2
# 3   E. 37th Street and Blue Ridge Cutoff       0        0
# 4                        Pleasant Street       1        0
# 5                         Westpark Drive       0        2
# 6                  2700 block 6th Avenue       0        1
# 7          3000 block of Woodland Avenue       0        1
# 8            400 block of S. 12th Street       0        0
#
#                                 8
# 0                      Operations
# 0                            None
# 1   View Incident\nView Source\n]
# 2   View Incident\nView Source\n]
# 3   View Incident\nView Source\n]
# 4   View Incident\nView Source\n]
# 5   View Incident\nView Source\n]
# 6   View Incident\nView Source\n]
# 7   View Incident\nView Source\n]
# 8   View Incident\nView Source\n]

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#    Incident ID  Incident Date   year            State         City Or County  \
# 0  Incident ID  Incident Date   year            State         City Or County
# 0            ]           None   None             None                   None
# 1       480589    December 31   2015         New York   New York (Manhattan)
# 2       476987    December 31   2015   North Carolina                 Durham
# 3       476984    December 31   2015         Missouri            Kansas City
#
#                                  Address  Killed  Injured  \
# 0                                Address  Killed  Injured
# 0                                   None    None     None
# 1                         Sherman Street       0        1
# 2                       433 Pilot Street       0        2
# 3   E. 37th Street and Blue Ridge Cutoff       0        0
#
#                        Operations
# 0                      Operations
# 0                            None
# 1   View Incident\nView Source\n]
# 2   View Incident\nView Source\n]
# 3   View Incident\nView Source\n]

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 0 to 441
# Data columns (total 9 columns):
# Incident ID       443 non-null object
# Incident Date     426 non-null object
# year              426 non-null object
# State             426 non-null object
# City Or County    426 non-null object
# Address           426 non-null object
# Killed            426 non-null object
# Injured           426 non-null object
# Operations        426 non-null object
# dtypes: object(9)
# memory usage: 34.6+ KB
# (443, 9)

# %%
df6 = df5.dropna(axis=0, how='any')

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   Incident ID Incident Date   year            State         City Or County  \
# 1      480589   December 31   2015         New York   New York (Manhattan)
# 2      476987   December 31   2015   North Carolina                 Durham
# 3      476984   December 31   2015         Missouri            Kansas City
# 4      476351   December 31   2015    Massachusetts            New Bedford
# 5      476966   December 31   2015   North Carolina              Charlotte
#
#                                  Address Killed Injured  \
# 1                         Sherman Street      0       1
# 2                       433 Pilot Street      0       2
# 3   E. 37th Street and Blue Ridge Cutoff      0       0
# 4                        Pleasant Street      1       0
# 5                         Westpark Drive      0       2
#
#                        Operations
# 1   View Incident\nView Source\n]
# 2   View Incident\nView Source\n]
# 3   View Incident\nView Source\n]
# 4   View Incident\nView Source\n]
# 5   View Incident\nView Source\n]

# %%
df7['Operations'] = df7['Operations'].str.strip(']').str.strip('\n')
df7.head()
# Out:
#   Incident ID Incident Date   year            State         City Or County  \
# 1      480589   December 31   2015         New York   New York (Manhattan)
# 2      476987   December 31   2015   North Carolina                 Durham
# 3      476984   December 31   2015         Missouri            Kansas City
# 4      476351   December 31   2015    Massachusetts            New Bedford
# 5      476966   December 31   2015   North Carolina              Charlotte
#
#                                  Address Killed Injured  \
# 1                         Sherman Street      0       1
# 2                       433 Pilot Street      0       2
# 3   E. 37th Street and Blue Ridge Cutoff      0       0
# 4                        Pleasant Street      1       0
# 5                         Westpark Drive      0       2
#
#                     Operations
# 1   View Incident\nView Source
# 2   View Incident\nView Source
# 3   View Incident\nView Source
# 4   View Incident\nView Source
# 5   View Incident\nView Source

# %%
df7 = df7.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df7.to_csv("gunviolence2015_db.csv")

# %%
# Create engine using the `gunviolence_db.sqlite` database file
#engine = create_engine("sqlite:///../project2_team4/gunviolence_db.sqlite")

# %%
#df7.to_sql("gunviolence2019_db", con=engine)
