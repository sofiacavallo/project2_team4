# %%
# Dependencies
# Declare Dependencies 
from splinter import Browser
from bs4 import BeautifulSoup
from flask import request
import html5lib
import pandas as pd
import lxml
import requests

# %%
# Choose the executable path to driver 
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL
url = 'https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/table/?sort=date'
browser.visit(url)

# %%
# HTML Object
html = browser.html

# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <html class="js geolocation svg inlinesvg cors" lang="en">
#  <head>
#   <style type="text/css">
#    @charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}
#   </style>
#   <title>
#    Mass Shootings in America — Opendatasoft
#   </title>
#   <link href="/static/vendor/font-awesome-4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/static/vendor/normalize/normalize.css" rel="stylesheet" type="text/css"/>
#   <link href="/static/pictos/odsui/odsui.css" rel="stylesheet" type="text/css"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="en" http-equiv="Content-Language"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://s3-eu-west-1.amazonaws.com/aws-ec2-eu-1-opendatasoft-staticfileset/public/favicon?tstamp=155775855809" rel="shortcut icon"/>
#   <!--[if lte IE 9]>
#             <script>
#             // Stub the console object to avoid accidental leftover logs breaking IE <=9
#             if (!window.console) window.console = {};
#             if (!window.console.log) window.console.log = function () { };
#             </script>
#             <script src="/static/vendor/base64-polyfill/base64.min.js" type="text/javascript"></script>
#         <![endif]-->
#   <link href="https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/table/" hreflang="en" rel="alternate"/>
#   <link href="https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/table/?sort=date&amp;flg=fr" hreflang="fr" rel="alternate"/>
#   <link href="https://public.opendatasoft.com/static/custom/public/img/ods-logo-transparent.png" rel="image_src"/>
#   <meta content="https://public.opendatasoft.com/static/custom/public/img/ods-logo-transparent.png" property="og:image"/>
#   <meta content="https://public.opendatasoft.com/static/custom/public/img/ods-logo-transparent.png" name="thumbnail"/>
#   <link href="/static/compressed/css/be3178484bc9.css" rel="stylesheet" type="text/css"/>
#   <link href="https://s3-eu-west-1.amazonaws.com/aws-ec2-eu-1-opendatasoft-staticfileset/public/stylesheet/2.css" rel="stylesheet" type="text/css"/>
#   <link href="https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/" rel="canonical"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Mass Shootings in America" name="twitter:title"/>
#   <meta content="The Stanford Mass Shootings of America (MSA) data is a curated set of spatial and temporal data about mass shootings in America, taken from online media sources. It is an attempt to facilitate research on gun violence in the US by making raw data more accessible.Please click here for more information." name="twitter:description"/>
#   <meta content="https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/table/?sort=date" name="twitter:url"/>
#   <meta content="https://public.opendatasoft.com/static/ods/imgv4/social-images/social_media_image_table.png" name="twitter:image"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Mass Shootings in America" property="og:title"/>
#   <meta content="The Stanford Mass Shootings of America (MSA) data is a curated set of spatial and temporal data about mass shootings in America, taken from online media sources. It is an attempt to facilitate research on gun violence in the US by making raw data more accessible.Please click here for more information." property="og:description"/>
#   <meta content="https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/table/?sort=date" property="og:url"/>
#   <meta content="https://public.opendatasoft.com/static/ods/imgv4/social-images/social_media_image_table.png" property="og:image"/>
#   <meta content="200" property="og:image:width"/>
#   <meta content="200" property="og:image:height"/>
#   <meta content="mass shooting, crime, United States" name="keywords"/>
#   <meta content="The Stanford Mass Shootings of America (MSA) data is a curated set of spatial and temporal data about mass shootings in America, taken from online media sources. It is an attempt to facilitate research on gun violence in the US by making raw data more accessible.Please click here for more information." name="description"/>
#   <link href="http://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/rss/?sort=date" rel="alternate" title="Mass Shootings in America" type="application/rss+xml"/>
#   <link href="http://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/atom/?sort=date" rel="alternate" title="Mass Shootings in America" type="application/atom+xml"/>
#   <base href="/explore/dataset/mass-shootings-in-america/"/>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-41201218-1', {'name': 'ods'});
#
#     ga(function() {
#     var trackers = ga.getAll();
#     for (var i=0; i<trackers.length; ++i) {
#         var tracker = trackers[i];
#         if (tracker.get('name') == 'ods') {
#             tracker.set('dimension1', 'public');
#         }
#
#     }
# });
#   </script>
#   <script src="" type="text/javascript">
#   </script>
#   <style id="footer-adjuster">
#    .ods-content {margin-bottom: -40px}
# .ods-content:after {height: 40px}
#   </style>
#  </head>
#  <body class="" style="overflow-y: initial;">
#   <div class="ods-content">
#    <header class="ng-scope" ng-controller="HeaderController">
#     <nav breakpoint="1000" class="ods-front-header ng-isolate-scope" ods-responsive-menu="">
#      <div class="ods-responsive-menu-placeholder">
#       <button aria-label="Open menu" class="ods-responsive-menu-placeholder__toggle" ng-click="toggleMenu()" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-bars">
#        </i>
#       </button>
#       <div class="ods-responsive-menu-placeholder__container" ng-transclude="">
#        <a class="ods-front-header__portal-brand ng-scope" href="/">
#         <img alt="public" class="ods-front-header__logo" src="https://s3-eu-west-1.amazonaws.com/aws-ec2-eu-1-opendatasoft-staticfileset/public/logo?tstamp=155775856308"/>
#        </a>
#       </div>
#      </div>
#      <div class="ods-responsive-menu-collapsible">
#       <div class="ods-responsive-menu-collapsible__backdrop">
#       </div>
#       <div class="ods-responsive-menu-collapsible__container">
#        <div class="ods-responsive-menu-collapsible__toggle">
#         <button aria-label="Close menu" class="ods-responsive-menu-collapsible__toggle-button" ng-click="toggleMenu()" translate="aria-label">
#          <i aria-hidden="true" class="fa fa-close">
#          </i>
#         </button>
#        </div>
#        <div class="ods-responsive-menu-collapsible__content" ng-transclude="">
#         <ul class="ods-front-header__languages ng-scope">
#          <li class="ods-front-header__language">
#           <a class="ods-front-header__language__choice ods-front-header__link ods-front-header__link--active" href="#" ods-language-switcher="en" title="English">
#            en
#           </a>
#          </li>
#          <li class="ods-front-header__language">
#           <a class="ods-front-header__language__choice ods-front-header__link" href="#" ods-language-switcher="fr" title="French">
#            fr
#           </a>
#          </li>
#         </ul>
#         <a class="ods-front-header__portal-brand ng-scope" href="/">
#          <img alt="public" class="ods-front-header__logo" src="https://s3-eu-west-1.amazonaws.com/aws-ec2-eu-1-opendatasoft-staticfileset/public/logo?tstamp=155775856308"/>
#          <span class="ods-front-header__portal-brand__text" ng-non-bindable="">
#          </span>
#         </a>
#         <ul class="ods-front-header__menu ng-scope">
#          <li class="ods-front-header__menu-item ods-front-header__menu-item--active" ng-non-bindable="">
#           <a aria-current="page" class="ods-front-header__menu-item-link ods-front-header__menu-item-link--active" href="/explore/">
#            Explore
#           </a>
#          </li>
#          <li class="ods-front-header__menu-item" ng-non-bindable="">
#           <a class="ods-front-header__menu-item-link" href="/map/">
#            Map Builder
#           </a>
#          </li>
#          <li class="ods-front-header__menu-item" ng-non-bindable="">
#           <a class="ods-front-header__menu-item-link" href="/api/">
#            API
#           </a>
#          </li>
#          <li class="ods-front-header__menu-item" ng-non-bindable="">
#           <a class="ods-front-header__menu-item-link" href="/chart/">
#            Chart Builder
#           </a>
#          </li>
#         </ul>
#         <ul class="ods-front-header__management-menu ng-scope">
#          <li class="ods-front-header__management-menu-item">
#           <a class="ods-front-header__management-menu-item-link" href="/login/">
#            <i aria-hidden="true" class="fa fa-sign-in">
#            </i>
#            Login
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <main class="main--dataset">
#     <div class="container-fluid ods-app-explore-dataset ng-scope" context="ctx" ctx-dataset-schema="\{&quot;datasetid&quot;: &quot;mass-shootings-in-america&quot;, &quot;metas&quot;: \{&quot;publisher&quot;: &quot;Stanford Geospatial Center and Stanford Libraries&quot;, &quot;domain&quot;: &quot;public&quot;, &quot;description&quot;: &quot;&lt;p&gt;The Stanford Mass Shootings of America (MSA) data is a curated set of spatial and temporal data about mass shootings in America, taken from online media sources. It is an attempt to facilitate research on gun violence in the US by making raw data more accessible.&lt;/p&gt;&lt;p&gt;Please\u00a0&lt;a href=\&quot;https://library.stanford.edu/projects/mass-shootings-america\&quot; target=\&quot;_blank\&quot;&gt;click here&lt;/a&gt; for\u00a0more information.&lt;/p&gt;&quot;, &quot;license&quot;: &quot;CC BY&quot;, &quot;records_count&quot;: 307, &quot;title&quot;: &quot;Mass Shootings in America&quot;, &quot;staged&quot;: false, &quot;federated&quot;: false, &quot;visibility&quot;: &quot;domain&quot;, &quot;modified&quot;: &quot;2017-10-09T14:28:18+00:00&quot;, &quot;language&quot;: &quot;en&quot;, &quot;theme&quot;: [&quot;Justice, Safety, Police, Crime&quot;], &quot;metadata_processed&quot;: &quot;2017-10-09T14:28:34+00:00&quot;, &quot;keyword&quot;: [&quot;mass shooting&quot;, &quot;crime&quot;, &quot;United States&quot;], &quot;data_processed&quot;: &quot;2017-10-09T14:28:33+00:00&quot;, &quot;references&quot;: &quot;Stanford Mass Shootings in America, courtesy of the Stanford Geospatial Center and Stanford Libraries&quot;, &quot;license_url&quot;: &quot;https://creativecommons.org/licenses/by/4.0/&quot;\}, &quot;has_records&quot;: true, &quot;data_visible&quot;: true, &quot;features&quot;: [&quot;geo&quot;, &quot;analyze&quot;, &quot;timeserie&quot;, &quot;custom_view&quot;], &quot;attachments&quot;: [], &quot;alternative_exports&quot;: [], &quot;fields&quot;: [\{&quot;type&quot;: &quot;double&quot;, &quot;name&quot;: &quot;caseid&quot;, &quot;label&quot;: &quot;CaseID&quot;\}, \{&quot;type&quot;: &quot;text&quot;, &quot;name&quot;: &quot;title&quot;, &quot;label&quot;: &quot;Title&quot;\}, \{&quot;type&quot;: &quot;text&quot;, &quot;name&quot;: &quot;location&quot;, &quot;label&quot;: &quot;Location&quot;\}, \{&quot;type&quot;: &quot;text&quot;, &quot;annotations&quot;: [\{&quot;name&quot;: &quot;facet&quot;\}], &quot;name&quot;: &quot;city&quot;, &quot;label&quot;: &quot;City&quot;\}, \{&quot;type&quot;: &quot;text&quot;, &quot;annotations&quot;: [\{&quot;name&quot;: &quot;facet&quot;\}], &quot;name&quot;: &quot;state&quot;, &quot;label&quot;: &quot;State&quot;\}, \{&quot;type&quot;: &quot;double&quot;, &quot;name&quot;: &quot;latitude&quot;, &quot;label&quot;: &quot;Latitude&quot;\}, \{&quot;type&quot;: &quot;double&quot;, &quot;name&quot;: &quot;longitude&quot;, &quot;label&quot;: &quot;Longitude&quot;\}, \{&quot;type&quot;: &quot;double&quot;, &quot;name&quot;: &quot;number_of_victim_fatalities&quot;, &quot;label&quot;: &quot;Number of Victim Fatalities&quot;\}, \{&quot;type&quot;: &quot;double&quot;, &quot;name&quot;: &quot;total_number_of_fatalities&quot;, &quot;label&quot;: &quot;Total Number of Fatalities&quot;\}, \{&quot;type&quot;: &quot;double&quot;, &quot;name&quot;: &quot;number_of_victims_injured&quot;, &quot;label&quot;: &quot;Number of Victims Injured&quot;\}, \{&quot;type&quot;: &quot;double&quot;, &quot;name&quot;: &quot;total_number_of_victims&quot;, &quot;label&quot;: &quot;Total Number of Victims&quot;\}, \{&quot;type&quot;: &quot;text&quot;, &quot;name&quot;: &quot;description&quot;, &quot;label&quot;: &quot;Description&quot;\}, \{&quot;type&quot;: &quot;date&quot;, &quot;name&quot;: &quot;date&quot;, &quot;label&quot;: &quot;Date&quot;\}, \{&quot;type&quot;: &quot;text&quot;, &quot;name&quot;: &quot;day_of_week&quot;, &quot;label&quot;: &quot;Day of Week&quot;\}, \{&quot;type&quot;: &quot;text&quot;, &quot;name&quot;: &quot;date_detailed&quot;, &quot;label&q ...
#      <div class="ods-notification-handler ng-scope ng-hide" ng-show="notificationList.length">
#       <!-- ngRepeat: notification in notificationList -->
#      </div>
#      <div class="ods-filters-summary" ng-class="{'ods-filters-summary--expanded': toggleState.expandedFilters}">
#       <div class="ods-filters-summary__count">
#        <span class="ods-filters-summary__count-number ng-binding">
#        </span>
#        <span class="ods-filters-summary__count-units" translate="" translate-n="ctx.nhits" translate-plural="records">
#         <span class="ng-scope">
#          records
#         </span>
#        </span>
#       </div>
#       <button class="ods-button ods-filters-summary__toggle" ng-click="toggleMobileFilters()">
#        <i aria-hidden="true" class="fa fa-expand" ng-class="{'fa-expand': !toggleState.expandedFilters, 'fa-compress': toggleState.expandedFilters}">
#        </i>
#        <span translate="">
#         <span class="ng-scope">
#          Filters
#         </span>
#        </span>
#       </button>
#      </div>
#      <div class="ods-filters" ng-class="{'ods-filters--expanded': toggleState.expandedFilters}">
#       <h2 class="ods-filters__count">
#        <span class="ods-filters__count-number ng-binding">
#        </span>
#        <span class="ods-filters__count-units" translate="" translate-n="ctx.nhits" translate-plural="records">
#         <span class="ng-scope">
#          records
#         </span>
#        </span>
#       </h2>
#       <h2 class="ods-filters__filters-summary ng-hide" ng-show="ctx.getActiveFilters().length">
#        <span class="ods-filter__filter-summary-title" translate="">
#         <span class="ng-scope">
#          Active filters
#         </span>
#        </span>
#        <a class="odswidget-clear-all-filters ng-isolate-scope" context="ctx" href="" ng-click="clearAll()">
#         <i aria-hidden="true" class="fa fa-ban">
#         </i>
#         <span translate="">
#          <span class="ng-scope">
#           Clear all
#          </span>
#         </span>
#        </a>
#       </h2>
#       <ul class="odswidget odswidget-filter-summary ng-isolate-scope" clear-all-button="false" context="ctx">
#        <!-- ngRepeat: refinement in refinements -->
#        <li class="odswidget-filter-summary__clear-all ng-hide" ng-show="clearAllButton &amp;&amp; refinements.length &gt; 0">
#         <a class="odswidget-clear-all-filters ng-isolate-scope" context="context" except="excludes" href="" ng-click="clearAll()">
#          <i aria-hidden="true" class="fa fa-ban">
#          </i>
#          <span translate="">
#           <span class="ng-scope">
#            Clear all
#           </span>
#          </span>
#         </a>
#        </li>
#       </ul>
#       <div class="ods-filters__no-filters" ng-hide="ctx.getActiveFilters().length">
#        <span translate="">
#         <span class="ng-scope">
#          No active filters
#         </span>
#        </span>
#       </div>
#       <h2 class="ods-filters__filters">
#        <span translate="">
#         <span class="ng-scope">
#          Filters
#         </span>
#        </span>
#       </h2>
#       <div autofocus="autofocus" class="odswidget odswidget-text-search ng-isolate-scope" context="ctx" placeholder="Search records...">
#        <form class="odswidget-text-search__form ng-pristine ng-valid" ng-submit="applySearch()">
#         <input aria-label="Search records..." class="odswidget-text-search__search-box ng-pristine ng-untouched ng-valid focus-ring" data-focus-ring-added="" id="" name="q" ng-model="searchExpression" placeholder="Search records..." type="text"/>
#         <button aria-label="Reset search" class="odswidget-text-search__reset ng-hide" ng-click="resetSearch()" ng-show="searchExpression" translate="aria-label" type="reset">
#          <span class="ods-aria-instructions" translate="">
#           <span class="ng-scope">
#            Reset
#           </span>
#          </span>
#          <i aria-hidden="true" class="fa fa-times-circle">
#          </i>
#         </button>
#         <button aria-label="Search in catalog" class="odswidget-text-search__submit" translate="aria-label" type="submit">
#          <span class="ods-aria-instructions" translate="">
#           <span class="ng-scope">
#            Submit
#           </span>
#          </span>
#          <i aria-hidden="true" class="fa fa-search">
#          </i>
#         </button>
#        </form>
#       </div>
#       <ods-facets class="ng-isolate-scope" context="ctx">
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="city" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="City" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="city" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in city" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="state" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="State" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="state" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in state" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="shooter_sex" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Shooter Sex" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="shooter_sex" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in shooter_sex" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="shooter_race" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Shooter Race" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="shooter_race" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in shooter_race" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="type_of_gun_general" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Type of Gun - General" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="type_of_gun_general" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in type_of_gun_general" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="fate_of_shooter_at_the_scene" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Fate of Shooter at the scene" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="fate_of_shooter_at_the_scene" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in fate_of_shooter_at_the_scene" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="shooter_s_cause_of_death" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Shooter's Cause of Death" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="shooter_s_cause_of_death" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in shooter_s_cause_of_death" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="school_related" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="School Related" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="school_related" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in school_related" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="place_type" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Place Type" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="place_type" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in place_type" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="relationship_to_incident_location" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Relationship to Incident Location" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="relationship_to_incident_location" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in relationship_to_incident_location" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="targeted_victim_s_general" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Targeted Victim/s - General" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="targeted_victim_s_general" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in targeted_victim_s_general" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="possible_motive_general" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Possible Motive - General" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="possible_motive_general" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in possible_motive_general" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="history_of_mental_illness_general" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="History of Mental Illness - General" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="history_of_mental_illness_general" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in history_of_mental_illness_general" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#        <div class="ng-scope ng-isolate-scope odswidget odswidget-facet" context="ctx" disjunctive="" hide-category-if="" hide-if-single-category="false" name="military_experience" ng-class="{'odswidget': true, 'odswidget-facet': true, 'odswidget-facet--disjunctive': disjunctive}" sort="" timerange-filter="" title="Military Experience" value-formatter="">
#         <!-- ngIf: title && ((categories.length && visible()) || displayTimerange()) -->
#         <!-- ngIf: displayTimerange() -->
#         <!-- ngIf: visible() -->
#         <ul categories="categories" class="odswidget-facet__category-list ng-scope ng-isolate-scope" facet-name="military_experience" hide-category-if="" ng-if="visible()" template="" value-formatter="" value-search="">
#          <li class="odswidget-facet__value-search ng-hide" ng-show="valueSearchEnabled">
#           <input aria-label="Search in military_experience" class="odswidget-facet__value-search-input ng-pristine ng-untouched ng-valid" ng-model="valueFilter" translate="aria-label"/>
#           <i class="odswidget-facet__value-search-cancel fa fa-times ng-hide" ng-click="valueFilter=''" ng-show="!!valueFilter">
#           </i>
#          </li>
#          <!-- ngRepeat: category in categories|filter:searchValue(valueFilter) -->
#          <!-- ngIf: !suggestMode && visibleItems < (filterInvisibleCategories(categories)|filter:searchValue(valueFilter)).length -->
#         </ul>
#         <!-- end ngIf: visible() -->
#        </div>
#       </ods-facets>
#      </div>
#      <div class="ods-dataset-visualization" ng-class="{'ods-dataset-visualization--full-width': !canAccessData()}">
#       <div class="ods-dataset-visualization__header">
#        <h1 class="ods-dataset-visualization__dataset-title">
#         <div class="odswidget-social-buttons ng-isolate-scope">
#          <!-- ngRepeat: (name, button) in activeButtons -->
#          <button aria-label="Share on Twitter" class="odswidget-social-buttons__button ng-scope" ng-click="openPopup(button)" ng-hide="name === 'email'" ng-repeat-start="(name, button) in activeButtons" type="button">
#           <i aria-hidden="true" class="fa fa-twitter" ng-class="button.icon">
#           </i>
#          </button>
#          <a aria-label="Share on Twitter" class="odswidget-social-buttons__button ng-scope ng-hide" href="https://twitter.com/intent/tweet?text=Mass%20Shootings%20in%20America%20%E2%80%94%20Opendatasoft&amp;url=https%3A%2F%2Fpublic.opendatasoft.com%2Fexplore%2Fdataset%2Fmass-shootings-in-america%2Ftable%2F%3Fsort%3Ddate" ng-href="https://twitter.com/intent/tweet?text=Mass%20Shootings%20in%20America%20%E2%80%94%20Opendatasoft&amp;url=https%3A%2F%2Fpublic.opendatasoft.com%2Fexplore%2Fdataset%2Fmass-shootings-in-america%2Ftable%2F%3Fsort%3Ddate" ng-repeat-end="" ng-show="name === 'email'">
#           <i aria-hidden="true" class="fa fa-twitter" ng-class="button.icon">
#           </i>
#          </a>
#          <!-- end ngRepeat: (name, button) in activeButtons -->
#          <button aria-label="Share on Facebook" class="odswidget-social-buttons__button ng-scope" ng-click="openPopup(button)" ng-hide="name === 'email'" ng-repeat-start="(name, button) in activeButtons" type="button">
#           <i aria-hidden="true" class="fa fa-facebook" ng-class="button.icon">
#           </i>
#          </button>
#          <a aria-label="Share on Facebook" class="odswidget-social-buttons__button ng-scope ng-hide" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fpublic.opendatasoft.com%2Fexplore%2Fdataset%2Fmass-shootings-in-america%2Ftable%2F%3Fsort%3Ddate" ng-href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fpublic.opendatasoft.com%2Fexplore%2Fdataset%2Fmass-shootings-in-america%2Ftable%2F%3Fsort%3Ddate" ng-repeat-end="" ng-show="name === 'email'">
#           <i aria-hidden="true" class="fa fa-facebook" ng-class="button.icon">
#           </i>
#          </a>
#          <!-- end ngRepeat: (name, button) in activeButtons -->
#          <button aria-label="Share on Linkedin" class="odswidget-social-buttons__button ng-scope" ng-click="openPopup(button)" ng-hide="name === 'email'" ng-repeat-start="(name, button) in activeButtons" type="button">
#           <i aria-hidden="true" class="fa fa-linkedin" ng-class="button.icon">
#           </i>
#          </button>
#          <a aria-label="Share on Linkedin" class="odswidget-social-buttons__button ng-scope ng-hide" href="https://www.linkedin.com/shareArticle?url=https%3A%2F%2Fpublic.opendatasoft.com%2Fexplore%2Fdataset%2Fmass-shootings-in-america%2Ftable%2F%3Fsort%3Ddate&amp;mini=true&amp;title=Mass%20Shootings%20in%20America%20%E2%80%94%20Opendatasoft&amp;source=Mass%20Shootings%20in%20America%20%E2%80%94%20Opendatasoft" ng-href="https://www.linkedin.com/shareArticle?url=https%3A%2F%2Fpublic.opendatasoft.com%2Fexplore%2Fdataset%2Fmass-shootings-in-america%2Ftable%2F%3Fsort%3Ddate&amp;mini=true&amp;title=Mass%20Shootings%20in%20America%20%E2%80%94%20Opendatasoft&amp;source=Mass%20Shootings%20in%20America%20%E2%80%94%20Opendatasoft" ng-repeat-end="" ng-show="name === 'email'">
#           <i aria-hidden="true" class="fa fa-linkedin" ng-class="button.icon">
#           </i>
#          </a>
#          <!-- end ngRepeat: (name, button) in activeButtons -->
#          <button aria-label="Share by email" class="odswidget-social-buttons__button ng-scope ng-hide" ng-click="openPopup(button)" ng-hide="name === 'email'" ng-repeat-start="(name, button) in activeButtons" type="button">
#           <i aria-hidden="true" class="fa fa-envelope" ng-class="button.icon">
#           </i>
#          </button>
#          <a aria-label="Share by email" class="odswidget-social-buttons__button ng-scope" href="mailto:?subject=Mass%20Shootings%20in%20America%20%E2%80%94%20Opendatasoft&amp;body=https%3A%2F%2Fpublic.opendatasoft.com%2Fexplore%2Fdataset%2Fmass-shootings-in-america%2Ftable%2F%3Fsort%3Ddate" ng-href="mailto:?subject=Mass%20Shootings%20in%20America%20%E2%80%94%20Opendatasoft&amp;body=https%3A%2F%2Fpublic.opendatasoft.com%2Fexplore%2Fdataset%2Fmass-shootings-in-america%2Ftable%2F%3Fsort%3Ddate" ng-repeat-end="" ng-show="name === 'email'">
#           <i aria-hidden="true" class="fa fa-envelope" ng-class="button.icon">
#           </i>
#          </a>
#          <!-- end ngRepeat: (name, button) in activeButtons -->
#         </div>
#         <span class="ods-dataset-visualization__dataset-title-text" ng-non-bindable="">
#          Mass Shootings in America
#         </span>
#        </h1>
#       </div>
#       <div class="ods-tabs ng-isolate-scope" default-tab="table" name="main" ng-show="panes.length" role="tablist" sync-to-url="true" sync-to-url-mode="path">
#        <div class="ods-tabs__tabs">
#         <!-- ngRepeat: pane in panes -->
#         <a class="ods-tabs__tab information ods-tabs__tab--horizontal" href="" ng-class="{'ods-tabs__tab--active': pane.selected,                      'ods-tabs__tab--horizontal': !layout || layout == 'horizontal',                      'ods-tabs__tab--simple-nav': layout == 'simple-nav'}" ng-click="selectTab(pane, true)" ng-hide="pane.hidden" ng-keypress="checkKey($event, pane)" ng-repeat="pane in panes" role="tab">
#          <i aria-hidden="true" class="fa fa-info-circle" ng-show="pane.icon">
#          </i>
#          Information
#          <!-- ngIf: pane.count|isDefined -->
#         </a>
#         <!-- end ngRepeat: pane in panes -->
#         <a class="ods-tabs__tab table ods-tabs__tab--active ods-tabs__tab--horizontal" href="" ng-class="{'ods-tabs__tab--active': pane.selected,                      'ods-tabs__tab--horizontal': !layout || layout == 'horizontal',                      'ods-tabs__tab--simple-nav': layout == 'simple-nav'}" ng-click="selectTab(pane, true)" ng-hide="pane.hidden" ng-keypress="checkKey($event, pane)" ng-repeat="pane in panes" role="tab">
#          <i aria-hidden="true" class="fa fa-table" ng-show="pane.icon">
#          </i>
#          Table
#          <!-- ngIf: pane.count|isDefined -->
#         </a>
#         <!-- end ngRepeat: pane in panes -->
#         <a class="ods-tabs__tab map ods-tabs__tab--horizontal" href="" ng-class="{'ods-tabs__tab--active': pane.selected,                      'ods-tabs__tab--horizontal': !layout || layout == 'horizontal',                      'ods-tabs__tab--simple-nav': layout == 'simple-nav'}" ng-click="selectTab(pane, true)" ng-hide="pane.hidden" ng-keypress="checkKey($event, pane)" ng-repeat="pane in panes" role="tab">
#          <i aria-hidden="true" class="fa fa-globe" ng-show="pane.icon">
#          </i>
#          Map
#          <!-- ngIf: pane.count|isDefined -->
#         </a>
#         <!-- end ngRepeat: pane in panes -->
#         <a class="ods-tabs__tab analyze ods-tabs__tab--horizontal" href="" ng-class="{'ods-tabs__tab--active': pane.selected,                      'ods-tabs__tab--horizontal': !layout || layout == 'horizontal',                      'ods-tabs__tab--simple-nav': layout == 'simple-nav'}" ng-click="selectTab(pane, true)" ng-hide="pane.hidden" ng-keypress="checkKey($event, pane)" ng-repeat="pane in panes" role="tab">
#          <i aria-hidden="true" class="fa fa-bar-chart" ng-show="pane.icon">
#          </i>
#          Analyze
#          <!-- ngIf: pane.count|isDefined -->
#         </a>
#         <!-- end ngRepeat: pane in panes -->
#         <a class="ods-tabs__tab custom ods-tabs__tab--horizontal" href="" ng-class="{'ods-tabs__tab--active': pane.selected,                      'ods-tabs__tab--horizontal': !layout || layout == 'horizontal',                      'ods-tabs__tab--simple-nav': layout == 'simple-nav'}" ng-click="selectTab(pane, true)" ng-hide="pane.hidden" ng-keypress="checkKey($event, pane)" ng-repeat="pane in panes" role="tab">
#          <i aria-hidden="true" class="fa fa-ambulance" ng-show="pane.icon">
#          </i>
#          Mass Shootings
#          <!-- ngIf: pane.count|isDefined -->
#         </a>
#         <!-- end ngRepeat: pane in panes -->
#         <a class="ods-tabs__tab export ods-tabs__tab--horizontal" href="" ng-class="{'ods-tabs__tab--active': pane.selected,                      'ods-tabs__tab--horizontal': !layout || layout == 'horizontal',                      'ods-tabs__tab--simple-nav': layout == 'simple-nav'}" ng-click="selectTab(pane, true)" ng-hide="pane.hidden" ng-keypress="checkKey($event, pane)" ng-repeat="pane in panes" role="tab">
#          <i aria-hidden="true" class="fa fa-download" ng-show="pane.icon">
#          </i>
#          Export
#          <!-- ngIf: pane.count|isDefined -->
#         </a>
#         <!-- end ngRepeat: pane in panes -->
#         <a class="ods-tabs__tab api ods-tabs__tab--horizontal" href="" ng-class="{'ods-tabs__tab--active': pane.selected,                      'ods-tabs__tab--horizontal': !layout || layout == 'horizontal',                      'ods-tabs__tab--simple-nav': layout == 'simple-nav'}" ng-click="selectTab(pane, true)" ng-hide="pane.hidden" ng-keypress="checkKey($event, pane)" ng-repeat="pane in panes" role="tab">
#          <i aria-hidden="true" class="fa fa-cogs" ng-show="pane.icon">
#          </i>
#          API
#          <!-- ngIf: pane.count|isDefined -->
#         </a>
#         <!-- end ngRepeat: pane in panes -->
#        </div>
#        <div ng-transclude="">
# ...
#               <i aria-hidden="true" class="fa fa- ng-hide" ng-show="pane.icon">
#               </i>
#               Widget
#               <!-- ngIf: pane.count|isDefined -->
#              </a>
#              <!-- end ngRepeat: pane in panes -->
#             </div>
#             <div ng-transclude="">
#              <div class="ods-tabs__pane ng-scope ods-tabs__pane--active ods-tabs__pane--simple-nav" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" role="tabpanel" translate="title">
#               <!-- ngIf: shown || !struct.autoUnload -->
#               <div class="ng-scope" ng-if="shown || !struct.autoUnload" ng-transclude="">
#                <div class="ods-form__addon-wrapper ods-form__addon-wrapper--fluid">
#                 <input aria-disabled="true" class="ods-form__control ng-pristine ng-untouched ng-valid ng-valid-url" id="" ng-model="value" ng-readonly="true" readonly="readonly" type="url"/>
#                 <button aria-label="Copy to clipboard" class="ods-form__addon ods-button" ng-click="copyToClipboard()" ods-autofocus="odsAutofocus" ods-tooltip="" ods-tooltip-direction="top" ods-tooltip-template="tooltipMessage" type="button">
#                  <i aria-hidden="true" class="fa fa-clipboard">
#                  </i>
#                 </button>
#                </div>
#               </div>
#               <!-- end ngIf: shown || !struct.autoUnload -->
#              </div>
#              <div class="ods-tabs__pane ng-scope ods-tabs__pane--simple-nav" icon="" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" role="tabpanel" translate="title">
#               <!-- ngIf: shown || !struct.autoUnload -->
#               <div class="ng-scope" ng-if="shown || !struct.autoUnload" ng-transclude="">
#                <!-- ngIf: !anonymousAccess -->
#                <div class="ods-form__addon-wrapper ods-form__addon-wrapper--fluid">
#                 <input aria-disabled="true" class="ods-form__control ng-pristine ng-untouched ng-invalid ng-invalid-url" id="" ng-model="value" ng-readonly="true" readonly="readonly" type="url"/>
#                 <button aria-label="Copy to clipboard" class="ods-form__addon ods-button" ng-click="copyToClipboard()" ods-autofocus="odsAutofocus" ods-tooltip="" ods-tooltip-direction="top" ods-tooltip-template="tooltipMessage" type="button">
#                  <i aria-hidden="true" class="fa fa-clipboard">
#                  </i>
#                 </button>
#                </div>
#                <div class="ods-embed-control__size-options ods-form__horizontal-controls ng-scope">
#                 <select class="ods-form__control ng-pristine ng-untouched ng-valid" ng-model="size" ng-options="s as s.label for s in sizes">
#                  <option label="400 × 300" selected="selected" value="object:470">
#                   400 × 300
#                  </option>
#                  <option label="600 × 450" value="object:471">
#                   600 × 450
#                  </option>
#                  <option label="800 × 600" value="object:472">
#                   800 × 600
#                  </option>
#                  <option label="Custom size" value="object:473">
#                   Custom size
#                  </option>
#                 </select>
#                 <span class="ods-form__horizontal-controls ng-hide" dir="ltr" ng-show="size.name === 'custom'">
#                  <input class="ods-form__control ng-pristine ng-untouched ng-valid ng-valid-min" min="0" ng-model="size.width" step="1" type="number"/>
#                  ×
#                  <input class="ods-form__control ng-pristine ng-untouched ng-valid ng-valid-min" min="0" ng-model="size.height" step="1" type="number"/>
#                 </span>
#                </div>
#                <div class="ods-embed-control__misc-options ng-scope">
#                 <!-- ngIf: !forceEmbedDatasetCard -->
#                 <label class="ods-embed-control__misc-option ng-scope" ng-if="!forceEmbedDatasetCard">
#                  <input class="ng-pristine ng-untouched ng-valid" ng-model="embedUrlOptions.datasetcard" type="checkbox"/>
#                  <small>
#                   <span translate="">
#                    <span class="ng-scope">
#                     Display dataset information card
#                    </span>
#                   </span>
#                  </small>
#                 </label>
#                 <!-- end ngIf: !forceEmbedDatasetCard -->
#                 <label class="ods-embed-control__misc-option ng-hide" ng-show="embedType === 'map'">
#                  <input class="ng-pristine ng-untouched ng-valid" ng-model="embedUrlOptions.static" type="checkbox"/>
#                  <small>
#                   <span translate="">
#                    <span class="ng-scope">
#                     Lock map's zoom and position
#                    </span>
#                   </span>
#                  </small>
#                 </label>
#                 <label class="ods-embed-control__misc-option ng-hide" ng-show="embedType === 'map'">
#                  <input class="ng-pristine ng-untouched ng-valid" ng-model="mapOptions.scrollWheelZoom" type="checkbox"/>
#                  <small translate="">
#                   <span class="ng-scope">
#                    Enable zooming in and out with the mouse wheel
#                   </span>
#                  </small>
#                 </label>
#                </div>
#               </div>
#               <!-- end ngIf: shown || !struct.autoUnload -->
#              </div>
#              <div class="ods-tabs__pane ng-scope ods-tabs__pane--simple-nav" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" ng-show="widgetCode" role="tabpanel" translate="title">
#               <!-- ngIf: shown || !struct.autoUnload -->
#               <div class="ng-scope" ng-if="shown || !struct.autoUnload" ng-transclude="">
#                <div class="ods-form__addon-wrapper ods-form__addon-wrapper--fluid undefined ng-scope">
#                 <textarea class="ods-form__control ng-pristine ng-untouched ng-valid" dir="ltr" ng-model="value" ng-readonly="true" readonly="readonly" type="text">    </textarea>
#                 <button class="ods-form__addon ods-button" ng-click="copyToClipboard()" ods-autofocus="odsAutofocus" ods-tooltip="" ods-tooltip-direction="top" ods-tooltip-template="tooltipMessage" type="button">
#                  <i class="fa fa-clipboard">
#                  </i>
#                 </button>
#                </div>
#               </div>
#               <!-- end ngIf: shown || !struct.autoUnload -->
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <!-- end ngIf: shown || !struct.autoUnload -->
#         </div>
#         <div class="ods-dataset-visualization__tab-map ods-tabs__pane ng-scope ods-tabs__pane--horizontal" do-not-register="!ctx.dataset.hasFeature('geo')" icon="globe" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" pane-auto-unload="true" role="tabpanel" slug="map" translate="title">
#          <!-- ngIf: shown || !struct.autoUnload -->
#         </div>
#         <div class="ods-tabs__pane ng-scope ods-tabs__pane--horizontal" do-not-register="!ctx.dataset.hasFeature('analyze')" icon="bar-chart" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" pane-auto-unload="true" role="tabpanel" slug="analyze" translate="title">
#          <!-- ngIf: shown || !struct.autoUnload -->
#         </div>
#         <div class="ods-tabs__pane ng-scope ods-tabs__pane--horizontal" do-not-register="!ctx.dataset.hasFeature('image')" icon="picture-o" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" pane-auto-unload="true" role="tabpanel" slug="images" title="Images" translate="title">
#          <!-- ngIf: shown || !struct.autoUnload -->
#         </div>
#         <div class="ods-tabs__pane ng-scope ods-tabs__pane--horizontal" do-not-register="!ctx.dataset.hasFeature('calendar')" icon="calendar" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" pane-auto-unload="true" role="tabpanel" slug="calendar" title="Calendar" translate="title">
#          <!-- ngIf: shown || !struct.autoUnload -->
#         </div>
#         <div class="ods-tabs__pane ng-scope ods-tabs__pane--horizontal" do-not-register="!ctx.dataset.hasFeature('custom_view')" icon="ambulance" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" pane-auto-unload="true" role="tabpanel" slug="custom" title="Mass Shootings">
#          <!-- ngIf: shown || !struct.autoUnload -->
#         </div>
#         <div class="ods-tabs__pane ng-scope ods-tabs__pane--horizontal" icon="download" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" pane-auto-unload="true" role="tabpanel" slug="export" translate="title">
#          <!-- ngIf: shown || !struct.autoUnload -->
#         </div>
#         <div class="ods-tabs__pane ng-scope ods-tabs__pane--horizontal" icon="cogs" ng-class="{'ods-tabs__pane--active':struct.selected,                'ods-tabs__pane--horizontal': !layout || layout == 'horizontal',                'ods-tabs__pane--simple-nav': layout == 'simple-nav'}" pane-auto-unload="true" role="tabpanel" slug="api" translate="title">
#          <!-- ngIf: shown || !struct.autoUnload -->
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </main>
#   </div>
#   <footer class="ng-scope" ng-controller="FooterController">
#    <div class="ods-front-footer">
#     <a class="ods-front-footer__ods-logo" href="//www.opendatasoft.com">
#      <img alt="Opendatasoft, data management platform" class="ods-front-footer__ods-logo-img" src="/static/ods/imgv4/logo-ods_small_darkblue.svg"/>
#     </a>
#     <a class="ods-front-footer__legal ods-front-footer__link" href="/terms/terms-and-conditions/" target="_blank">
#      Terms and conditions
#     </a>
#     <a class="ods-front-footer__legal ods-front-footer__link" href="/terms/privacy-policy/" target="_blank">
#      Privacy policy
#     </a>
#     <ul class="ods-front-footer__languages">
#      <li class="ods-front-footer__language">
#       <a class="ods-front-footer__language__choice ods-front-footer__link ods-front-footer__link--active" href="#" hreflang="en" ods-language-switcher="en" title="English">
#        en
#       </a>
#      </li>
#      <li class="ods-front-footer__language">
#       <a class="ods-front-footer__language__choice ods-front-footer__link" href="#" hreflang="fr" ods-language-switcher="fr" title="French">
#        fr
#       </a>
#      </li>
#     </ul>
#    </div>
#   </footer>
#   <script src="/static/compressed/js/61812fc5f597.js" type="text/javascript">
#   </script>
#   <script src="/static/compressed/js/9262dc8ac62c.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var app = angular.module('ods.core.config', []);
#
#
#             app.factory("domainConfig", [function() {
#                 return {"languages": ["en", "fr"], "explore.reuse": true, "explore.dataset_catalog_separate_languages": null, "explore.disable_analyze": false, "explore.enable_api_tab": true};
#             }]);
#
#
#             app.factory("config", [function() {
#                 return {
#                     DATASET_ID: 'mass-shootings-in-america',
#                     LANGUAGE: 'en',
#                     AVAILABLE_LANGUAGES: ["en", "fr"],
#                     USER: null,
#                     FQ_USERNAME: null,
#                     BRAND_HOSTNAME: "opendatasoft.com",
#                     DEFAULT_BASEMAP: {"jawg_apikey": "4cKtE4Rze1HrvxWa9a7mdolSk10lVThTFC8zadQYMIMxTjkpTeIDJAAmhReDGnCH", "jawg_odsdomain": "public", "provider": "jawg.streets"},
#
#                     DOMAIN_ID: 'public',
#                     ANONYMOUS_ACCESS_ENABLED: 'true',
#                     FEEDBACK: true,
#                     RESOURCE_DOWNLOAD_CONDITIONS: false,
#                     PARENT_DOMAIN: true,
#
#                     MINUTE_LEVEL_SCHEDULING: true,
#                     CATALOG_SEARCH_BOOSTING_ENABLED: false,
#
#                     CENTRALSTORE: true,
#                     FORCE_DEBUG_LOGGER: false,
#                     RECAPTCHA_PUBLIC_KEY: '6LflroEUAAAAAH1LD8LksjNLDrYFfDp1_bf-D_RD',
#                     REQUEST_ID: 'c128339cf01e118d96e5922296d11294',
#                     CSRF_TOKEN: "<input type='hidden' name='csrfmiddlewaretoken' value='WV27u7X18D6MvE3JRGhGQ6TVvbIbMV6YPJGsJCFB9AP00a5OJE6dhFMcngzzKqNc' />"
#                 }
#             }]);
#   </script>
#   <script src="/static/compressed/js/d8c4fb26c98f.js" type="text/javascript">
#   </script>
#   <script src="/static/ods/js/supported-browsers-message.js" type="text/javascript">
#   </script>
#   <script src="/static/compressed/js/bffc26755f1d.js" type="text/javascript">
#   </script>
#   <script src="/static/compressed/js/561ebf4e228e.js" type="text/javascript">
#   </script>
#   <script src="/static/compressed/js/f62ee4d0dc14.js" type="text/javascript">
#   </script>
#   <script type="application/ld+json">
#    {
#         "@context":"http://schema.org/",
#         "@type":"Dataset",
#         "name":"Mass Shootings in America",
#         "description":"The Stanford Mass Shootings of America (MSA) data is a curated set of spatial and temporal data about mass shootings in America, taken from online media sources. It is an attempt to facilitate research on gun violence in the US by making raw data more accessible.Please click here for more information.",
#         "url":"https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/",
#         "dateModified": "2017-10-09T14:28:18+00:00"
#         ,
#         "keywords": ["mass shooting", "crime", "United States"]
#
#     ,
#         "distribution": [
#
#             {
#                 "@type":"DataDownload",
#                 "encodingFormat":"CSV",
#                 "contentUrl":"https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/download?format=csv"
#             },
#
#             {
#                 "@type":"DataDownload",
#                 "encodingFormat":"JSON",
#                 "contentUrl":"https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/download?format=json"
#             },
#
#             {
#                 "@type":"DataDownload",
#                 "encodingFormat":"Excel",
#                 "contentUrl":"https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/download?format=xls"
#             },
#
#             {
#                 "@type":"DataDownload",
#                 "encodingFormat":"GeoJSON",
#                 "contentUrl":"https://public.opendatasoft.com/explore/dataset/mass-shootings-in-america/download?format=geojson"
#             }
#
#         ]
#
#     ,
#     "license": "CC BY"
#
#     }
#   </script>
#   <div class="ods-tooltip" style="display: none;">
#   </div>
#  </body>
# </html>

# %%
my_table =soup.find('div',{'class':'odswidget-table__records'})
my_table
# Out:
# <div class="odswidget-table__records"> <table class="odswidget-table__internal-table" infinite-scroll="loadMore()" infinite-scroll-disabled="fetching" infinite-scroll-distance="1"> <thead class="odswidget-table__internal-table-header"> <tr> <th class="odswidget-table__header-cell odswidget-table__header-cell--spinner"><div class="odswidget-table__cell-container"><svg class="odswidget-spinner--large odswidget-spinner odswidget-spinner--svg" ng-show="fetching" version="1.1" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"> <rect class="odswidget-spinner__cell-11" height="30" width="30" x="0" y="0"></rect> <rect class="odswidget-spinner__cell-12" height="30" width="30" x="35" y="0"></rect> <rect class="odswidget-spinner__cell-13" height="30" width="30" x="70" y="0"></rect> <rect class="odswidget-spinner__cell-21" height="30" width="30" x="0" y="35"></rect> <rect class="odswidget-spinner__cell-22" height="30" width="30" x="35" y="35"></rect> <rect class="odswidget-spinner__cell-23" height="30" width="30" x="70" y="35"></rect> <rect class="odswidget-spinner__cell-31" height="30" width="30" x="0" y="70"></rect> <rect class="odswidget-spinner__cell-32" height="30" width="30" x="35" y="70"></rect> <rect class="odswidget-spinner__cell-33" height="30" width="30" x="70" y="70"></rect></svg></div></th> <!-- ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray --><th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="caseid"> <div class="odswidget-table__cell-container"> <span class="ng-binding" ng-bind="field.label">CaseID</span> <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title"> <button aria-label="Sort column CaseID in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up"></i> </button> <button aria-label="Sort column CaseID in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down"></i> </button> </div> </div> </th><!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray --><th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="title"> <div class="odswidget-table__cell-container"> <span class="ng-binding" ng-bind="field.label">Title</span> <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title"> <button aria-label="Sort column Title in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up"></i> </button> <button aria-label="Sort column Title in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down"></i> </button> </div> </div> </th><!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray --><th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="location"> <div class="odswidget-table__cell-container"> <span class="ng-binding" ng-bind="field.label">Location</span> <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title"> <button aria-label="Sort column Location in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sor ...

# %%
tables=my_table.findAll('table')
for table in tables:
    print(table.prettify())
# Out:
# <table class="odswidget-table__internal-table" infinite-scroll="loadMore()" infinite-scroll-disabled="fetching" infinite-scroll-distance="1">
#  <thead class="odswidget-table__internal-table-header">
#   <tr>
#    <th class="odswidget-table__header-cell odswidget-table__header-cell--spinner">
#     <div class="odswidget-table__cell-container">
#      <svg class="odswidget-spinner--large odswidget-spinner odswidget-spinner--svg" ng-show="fetching" version="1.1" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg">
#       <rect class="odswidget-spinner__cell-11" height="30" width="30" x="0" y="0">
#       </rect>
#       <rect class="odswidget-spinner__cell-12" height="30" width="30" x="35" y="0">
#       </rect>
#       <rect class="odswidget-spinner__cell-13" height="30" width="30" x="70" y="0">
#       </rect>
#       <rect class="odswidget-spinner__cell-21" height="30" width="30" x="0" y="35">
#       </rect>
#       <rect class="odswidget-spinner__cell-22" height="30" width="30" x="35" y="35">
#       </rect>
#       <rect class="odswidget-spinner__cell-23" height="30" width="30" x="70" y="35">
#       </rect>
#       <rect class="odswidget-spinner__cell-31" height="30" width="30" x="0" y="70">
#       </rect>
#       <rect class="odswidget-spinner__cell-32" height="30" width="30" x="35" y="70">
#       </rect>
#       <rect class="odswidget-spinner__cell-33" height="30" width="30" x="70" y="70">
#       </rect>
#      </svg>
#     </div>
#    </th>
#    <!-- ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="caseid">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       CaseID
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column CaseID in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column CaseID in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="title">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Title
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Title in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Title in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="location">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Location
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Location in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Location in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="city">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       City
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column City in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column City in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="state">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       State
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column State in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column State in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="latitude">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Latitude
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Latitude in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Latitude in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="longitude">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Longitude
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Longitude in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Longitude in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="number_of_victim_fatalities">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Number of Victim Fatalities
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Number of Victim Fatalities in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Number of Victim Fatalities in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="total_number_of_fatalities">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Total Number of Fatalities
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Total Number of Fatalities in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Total Number of Fatalities in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="number_of_victims_injured">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Number of Victims Injured
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Number of Victims Injured in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Number of Victims Injured in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="total_number_of_victims">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Total Number of Victims
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Total Number of Victims in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Total Number of Victims in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="description">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Description
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Description in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Description in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="date">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Date
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Date in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Date in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="day_of_week">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Day of Week
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Day of Week in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Day of Week in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="date_detailed">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Date - Detailed
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Date - Detailed in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Date - Detailed in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="shooter_name">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Shooter Name
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Shooter Name in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Shooter Name in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="shooter_age_s">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Shooter Age(s)
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Shooter Age(s) in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Shooter Age(s) in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="average_shooter_age">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Average Shooter Age
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Average Shooter Age in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Average Shooter Age in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="shooter_sex">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Shooter Sex
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Shooter Sex in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Shooter Sex in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="shooter_race">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Shooter Race
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Shooter Race in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Shooter Race in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="type_of_gun_detailed">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Type of Gun - Detailed
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Type of Gun - Detailed in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Type of Gun - Detailed in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="type_of_gun_general">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Type of Gun - General
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Type of Gun - General in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Type of Gun - General in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="number_of_shotguns">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Number of Shotguns
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Number of Shotguns in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Number of Shotguns in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="number_of_rifles">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Number of Rifles
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Number of Rifles in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Number of Rifles in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="number_of_handguns">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Number of Handguns
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Number of Handguns in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Number of Handguns in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="total_number_of_guns">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Total Number of Guns
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Total Number of Guns in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Total Number of Guns in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="number_of_automatic_guns">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Number of Automatic Guns
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Number of Automatic Guns in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Number of Automatic Guns in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="number_of_semi_automatic_guns">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Number of Semi-Automatic Guns
#      </span>
#      <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Number of Semi-Automatic Guns in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Number of Semi-Automatic Guns in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="fate_of_shooter_at_the_scene">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Fate of Shooter at the scene
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Fate of Shooter at the scene in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Fate of Shooter at the scene in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="shooter_s_cause_of_death">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Shooter's Cause of Death
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Shooter's Cause of Death in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Shooter's Cause of Death in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="school_related">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       School Related
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column School Related in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column School Related in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="place_type">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Place Type
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Place Type in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Place Type in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="relationship_to_incident_location">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Relationship to Incident Location
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Relationship to Incident Location in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Relationship to Incident Location in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="targeted_victim_s_detailed">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Targeted Victim/s - Detailed
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Targeted Victim/s - Detailed in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Targeted Victim/s - Detailed in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="targeted_victim_s_general">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Targeted Victim/s - General
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Targeted Victim/s - General in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Targeted Victim/s - General in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="possible_motive_detailed">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Possible Motive - Detailed
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Possible Motive - Detailed in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Possible Motive - Detailed in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="possible_motive_general">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Possible Motive - General
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Possible Motive - General in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Possible Motive - General in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="history_of_mental_illness_detailed">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       History of Mental Illness - Detailed
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column History of Mental Illness - Detailed in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column History of Mental Illness - Detailed in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="history_of_mental_illness_general">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       History of Mental Illness - General
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column History of Mental Illness - General in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column History of Mental Illness - General in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="data_source_1">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Data Source 1
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Data Source 1 in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Data Source 1 in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="data_source_2">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Data Source 2
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Data Source 2 in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Data Source 2 in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="data_source_3">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Data Source 3
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Data Source 3 in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Data Source 3 in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="data_source_4">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Data Source 4
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Data Source 4 in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Data Source 4 in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="data_source_5">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Data Source 5
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Data Source 5 in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Data Source 5 in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="data_source_6">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Data Source 6
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Data Source 6 in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Data Source 6 in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="data_source_7">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Data Source 7
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Data Source 7 in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Data Source 7 in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="military_experience">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Military Experience
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Military Experience in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Military Experience in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="class">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       Class
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column Class in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column Class in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#    <th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="geopoint">
#     <div class="odswidget-table__cell-container">
#      <span class="ng-binding" ng-bind="field.label">
#       geopoint
#      </span>
#      <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title">
#       <button aria-label="Sort column geopoint in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up">
#        </i>
#       </button>
#       <button aria-label="Sort column geopoint in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label">
#        <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down">
#        </i>
#       </button>
#      </div>
#     </div>
#    </th>
#    <!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray -->
#   </tr>
#  </thead>
#  <tbody class="odswidget-table__records-tbody">
#  </tbody>
# </table>

# %%
rows =my_table.findAll('tr')
print(rows[:10])
# Out:
# [<tr> <th class="odswidget-table__header-cell odswidget-table__header-cell--spinner"><div class="odswidget-table__cell-container"><svg class="odswidget-spinner--large odswidget-spinner odswidget-spinner--svg" ng-show="fetching" version="1.1" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"> <rect class="odswidget-spinner__cell-11" height="30" width="30" x="0" y="0"></rect> <rect class="odswidget-spinner__cell-12" height="30" width="30" x="35" y="0"></rect> <rect class="odswidget-spinner__cell-13" height="30" width="30" x="70" y="0"></rect> <rect class="odswidget-spinner__cell-21" height="30" width="30" x="0" y="35"></rect> <rect class="odswidget-spinner__cell-22" height="30" width="30" x="35" y="35"></rect> <rect class="odswidget-spinner__cell-23" height="30" width="30" x="70" y="35"></rect> <rect class="odswidget-spinner__cell-31" height="30" width="30" x="0" y="70"></rect> <rect class="odswidget-spinner__cell-32" height="30" width="30" x="35" y="70"></rect> <rect class="odswidget-spinner__cell-33" height="30" width="30" x="70" y="70"></rect></svg></div></th> <!-- ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray --><th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="caseid"> <div class="odswidget-table__cell-container"> <span class="ng-binding" ng-bind="field.label">CaseID</span> <div class="odswidget-table__sort-icons" ng-show="isFieldSortable(field)" title="sort" translate="title"> <button aria-label="Sort column CaseID in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up"></i> </button> <button aria-label="Sort column CaseID in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down"></i> </button> </div> </div> </th><!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray --><th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="title"> <div class="odswidget-table__cell-container"> <span class="ng-binding" ng-bind="field.label">Title</span> <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title"> <button aria-label="Sort column Title in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up"></i> </button> <button aria-label="Sort column Title in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-icons__down"></i> </button> </div> </div> </th><!-- end ngRepeat: field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray --><th class="odswidget-table__header-cell ng-scope" ng-repeat="field in context.dataset.fields|fieldsForVisualization:'table'|fieldsFilter:displayedFieldsArray" title="location"> <div class="odswidget-table__cell-container"> <span class="ng-binding" ng-bind="field.label">Location</span> <div class="odswidget-table__sort-icons ng-hide" ng-show="isFieldSortable(field)" title="sort" translate="title"> <button aria-label="Sort column Location in ascending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-up odswidget-table__sort-icons__up"></i> </button> <button aria-label="Sort column Location in descending order" class="odswidget-table__sort-icon" tabindex="0" translate="aria-label"> <i aria-hidden="true" class="fa fa-chevron-down odswidget-table__sort-ico ...
