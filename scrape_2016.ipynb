# %%
# Declare Dependencies 
from splinter import Browser
from bs4 import BeautifulSoup
from flask import request
import html5lib
import pandas as pd
import lxml
import requests
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
import requests as rq
import re
import time 
import random

# %%
# Choose the executable path to driver 
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL
result = []
list_rows = []
#rows = []
for i in range(0, 17):
    base_url = f'https://www.gunviolencearchive.org/reports/total-number-of-incidents?page={i}&year=2016'
    r = rq.get(base_url)
    time.sleep(random.randint(1,5))
    
    soup = BeautifulSoup(r.text, 'html.parser')
    table_rows = soup.find_all('tr')
    #print('Number of results', len(table_rows))
    for tr in table_rows:
        row_td = tr.find_all('td')
    rows =soup.findAll('tr')
    row = [row.get_text().strip('\n') for row in rows]
    str_cells = str(row_td)
    cleantext = BeautifulSoup(str_cells, "lxml").get_text()
    rows =soup.findAll('tr')
    for row in rows:
        cells = row.find_all('td')
        str_cells = str(cells)
        clean = re.compile('<.*?>')
        clean2 = (re.sub(clean, '',str_cells))
        list_rows.append(clean2)

df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1  [739539, December 31, 2016, Virginia, Newport ...
# 2  [739764, December 31, 2016, Tennessee, Knoxvil...
# 3  [738899, December 31, 2016, Florida, Pensacola...
# 4  [741817, December 31, 2016, Pennsylvania, Lanc...
# 5  [739284, December 31, 2016, Maryland, Baltimor...
# 6  [1207480, December 31, 2016, New Hampshire, Ho...
# 7  [740110, December 31, 2016, California, Sacram...
# 8  [744523, December 31, 2016, New Mexico, Santa ...
# 9  [740888, December 31, 2016, Colorado, Colorado...

# %%
df
# Out:
#                                                      0
# 0                                                   []
# 1    [739539, December 31, 2016, Virginia, Newport ...
# 2    [739764, December 31, 2016, Tennessee, Knoxvil...
# 3    [738899, December 31, 2016, Florida, Pensacola...
# 4    [741817, December 31, 2016, Pennsylvania, Lanc...
# 5    [739284, December 31, 2016, Maryland, Baltimor...
# 6    [1207480, December 31, 2016, New Hampshire, Ho...
# 7    [740110, December 31, 2016, California, Sacram...
# 8    [744523, December 31, 2016, New Mexico, Santa ...
# 9    [740888, December 31, 2016, Colorado, Colorado...
# 10   [739346, December 31, 2016, Nebraska, Omaha, 2...
# 11   [739348, December 31, 2016, Nebraska, Omaha, 6...
# 12   [739066, December 31, 2016, Florida, Loxahatch...
# 13   [741322, December 31, 2016, Florida, Miami (Cu...
# 14   [741777, December 31, 2016, Florida, Kissimmee...
# 15   [746648, December 31, 2016, Wyoming, Casper (B...
# 16   [746647, December 31, 2016, Wyoming, Casper, 2...
# 17   [746644, December 31, 2016, Wyoming, Casper, 1...
# 18   [1030975, December 31, 2016, Illinois, Carbond...
# 19   [740880, December 31, 2016, Florida, Tampa, De...
# 20   [741738, December 31, 2016, North Carolina, Mo...
# 21   [754283, December 31, 2016, Colorado, Denver, ...
# 22   [746622, December 31, 2016, California, Pittsb...
# 23   [746614, December 31, 2016, California, Brentw...
# 24   [738771, December 31, 2016, Texas, Houston, 42...
# 25   [740875, December 31, 2016, Ohio, Newton Falls...
# 26                                                  []
# 27   [739253, December 31, 2016, Texas, Austin, Rei...
# 28   [741718, December 31, 2016, Texas, Houston, 63...
# 29   [739255, December 31, 2016, Minnesota, Perham,...
# ..                                                 ...
# 412  [737056, December 29, 2016, North Carolina, As...
# 11                         Omaha                      61st St and Ames Ave
# 12                   Loxahatchee                          13289 Compton Rd
# 13            Miami (Cutler Bay)               20549 Southwest 93rd Avenue
# 14                     Kissimmee                         3000 Parkway Blvd
# 15             Casper (Bar Nunn)                   2200 block of Tipton St
# 16                        Casper                  2000 block of Buffalo St
# 17                        Casper           1800 block of Brigham Young Ave
# 18                    Carbondale                                E Birch St
# 19                         Tampa                              Deerfield St
# 20                     Morganton                      1419 Havenwood Drive
# 21                        Denver                  3200 block of W 14th Ave
# 22                     Pittsburg                1600 block of Norine Drive
# 23                     Brentwood                                       N/A
# 24                       Houston                          4235 Oak Shadows
# 25                  Newton Falls                                Ridge Road
# 26                          None                                      None
# 27                        Austin                Reinli St and Sheridan Ave
# 28                       Houston                 6300 Block of Sherwood Dr
# 29                        Perham                          2nd St Southwest
# ..                           ...                                       ...
# 412                    Asheville                        1563 Patton Avenue
# 413                     Carthage                                       N/A
# 414                    Englewood                         3151 W Girard Ave
# 415                  Shelbyville                             16 Village Ln
# 416                         None                                      None
# 417                      Brooker                           County Road 231
# 418                   Fort Myers                      4719 Palm Beach Blvd
# 419                        Miami                       2370 NW 48th Street
# 420                      Raleigh                2900 block of Capital Blvd
# 421           Atlanta (Chamblee)                       4050 Buford Highway
# 422                 Indianapolis           7600 block of Little John Drive
# 423                 Jacksonville                        4324 Atlantic Blvd
# 424                      Orlando                        Meadowmouse Street
# 425                       Bostic                    202 Whippoorwill Drive
# 426                      Orlando         7000 block of West Colonial Drive
# 427                   Shreveport         5189 Shreveport Blanchard Highway
# 428                       Deland                  208 West Division Street
# 429                     Brisbane           San Bruno Ave and Bayshore Blvd
# 430                    Frederick                           22 Hillcrest Dr
# 431               Salt Lake City                                Wakara Way
# 432              Corona (Queens)                   64th Pl and Central Ave
# 433                 Battle Creek                         65 Stringham Road
# 434                         Gary                 1000 block of Burr Street
# 435                     Seminole                      109th Ave and CR 296
# 436   Spring Hill (Weeki Wachee)                           9227 Lake Drive
# 437                     Ligonier                        11405 N State Rd 5
# 438                   Greenville   Arlington Blvd and South Memorial Drive
# 439                 Hopkinsville                Boxwood Dr and Westwood Dr
# 440                 Indianapolis            1400 block of West 34th Street
# 441                      Norfolk                300 block of Mahone Avenue
#
#         6     7                               8
# 0    None  None                            None
# 1       0     1   View Incident\nView Source\n]
# 2       1     0   View Incident\nView Source\n]
# 3       1     1   View Incident\nView Source\n]
# 4       0     0   View Incident\nView Source\n]
# 5       0     1   View Incident\nView Source\n]
# 6       0     0   View Incident\nView Source\n]
# 7       0     0   View Incident\nView Source\n]
# 8       0     0   View Incident\nView Source\n]
# 9       0     0   View Incident\nView Source\n]
# 10      0     1   View Incident\nView Source\n]
# 11      0     1   View Incident\nView Source\n]
# 12      1     0   View Incident\nView Source\n]
# 13      1     0   View Incident\nView Source\n]
# 14      1     0   View Incident\nView Source\n]
# 15      0     0   View Incident\nView Source\n]
# 16      0     0   View Incident\nView Source\n]
# 17      0     0   View Incident\nView Source\n]
# 18      0     0   View Incident\nView Source\n]
# 19      0     1   View Incident\nView Source\n]
# 20      0     1   View Incident\nView Source\n]
# 21      0     1   View Incident\nView Source\n]
# 22      0     0   View Incident\nView Source\n]
# 23      0     0   View Incident\nView Source\n]
# 24      1     0   View Incident\nView Source\n]
# 25      1     0   View Incident\nView Source\n]
# 26   None  None                            None
# 27      0     1   View Incident\nView Source\n]
# 28      1     0   View Incident\nView Source\n]
# 29      0     1   View Incident\nView Source\n]
# ..    ...   ...                             ...
# 412     0     1   View Incident\nView Source\n]
# 413     0     0   View Incident\nView Source\n]
# 414     1     0   View Incident\nView Source\n]
# 415     0     0   View Incident\nView Source\n]
# 416  None  None                            None
# 417     0     0   View Incident\nView Source\n]
# 418     0     0   View Incident\nView Source\n]
# 419     0     0   View Incident\nView Source\n]
# 420     1     0   View Incident\nView Source\n]
# 421     1     0   View Incident\nView Source\n]
# 422     1     0   View Incident\nView Source\n]
# 423     0     1   View Incident\nView Source\n]
# 424     0     1   View Incident\nView Source\n]
# 425     0     1   View Incident\nView Source\n]
# 426     0     0   View Incident\nView Source\n]
# 427     0     1   View Incident\nView Source\n]
# 428     0     1   View Incident\nView Source\n]
# 429     0     0   View Incident\nView Source\n]
# 430     0     1   View Incident\nView Source\n]
# 431     0     0   View Incident\nView Source\n]
# 432     0     0   View Incident\nView Source\n]
# 433     0     0   View Incident\nView Source\n]
# 434     0     0   View Incident\nView Source\n]
# 435     0     0   View Incident\nView Source\n]
# 436     0     0   View Incident\nView Source\n]
# 437     0     0   View Incident\nView Source\n]
# 438     0     1   View Incident\nView Source\n]
# 439     0     0   View Incident\nView Source\n]
# 440     0     1   View Incident\nView Source\n]
# 441     0     0   View Incident\nView Source\n]
#
# [442 rows x 9 columns]

# %%
headers = rows[0].find_all('th')
headers = [header.get_text().strip('\n') for header in headers]
headers
# Out:
# ['Incident ID',
#  'Incident Date',
#  'State',
#  'City Or County',
#  'Address',
#  '# Killed',
#  '# Injured',
#  'Operations']

# %%
all_header = []
col_str = str(headers)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ["['Incident ID', 'Incident Date', 'State', 'City Or County', 'Address', '# Killed', '# Injured', 'Operations']"]

# %%
header = all_header[0].replace('[', '').replace(']', '').split(',')[:8]
header.insert(2, 'year')
# new_header = []
# for item in header:
#     new_header.append(item.strip())
header = [name.replace('"', '').replace("'", "").replace('#', '').strip() for name in header]
header
# Out:
# ['Incident ID',
#  'Incident Date',
#  'year',
#  'State',
#  'City Or County',
#  'Address',
#  'Killed',
#  'Injured',
#  'Operations']

# %%
header_df = pd.DataFrame(header).T
header_df.head()
# Out:
#              0              1     2      3               4        5       6  \
# 0  Incident ID  Incident Date  year  State  City Or County  Address  Killed
#
#          7           8
# 0  Injured  Operations

# %%
df.shape, header_df.shape
# Out:
# ((442, 9), (1, 9))

# %%
frames = [header_df, df]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#              0              1      2               3                      4  \
# 0  Incident ID  Incident Date   year           State         City Or County
# 0            ]           None   None            None                   None
# 1       739539    December 31   2016        Virginia           Newport News
# 2       739764    December 31   2016       Tennessee              Knoxville
# 3       738899    December 31   2016         Florida              Pensacola
# 4       741817    December 31   2016    Pennsylvania              Lancaster
# 5       739284    December 31   2016        Maryland              Baltimore
# 6      1207480    December 31   2016   New Hampshire               Hooksett
# 7       740110    December 31   2016      California             Sacramento
# 8       744523    December 31   2016      New Mexico   Santa Fe (La Cienga)
#
#                                5       6        7  \
# 0                        Address  Killed  Injured
# 0                           None    None     None
# 1                   Vernon Place       0        1
# 2            Highland View Drive       1        0
# 3              3 Talladega Trail       1        1
# 4     100 block of Chesapeake St       0        0
# 5   4600 block of Reistertown Rd       0        1
# 6                            N/A       0        0
# 7    43rd Ave and S Land Park Dr       0        0
# 8                   Camino Largo       0        0
#
#                                 8
# 0                      Operations
# 0                            None
# 1   View Incident\nView Source\n]
# 2   View Incident\nView Source\n]
# 3   View Incident\nView Source\n]
# 4   View Incident\nView Source\n]
# 5   View Incident\nView Source\n]
# 6   View Incident\nView Source\n]
# 7   View Incident\nView Source\n]
# 8   View Incident\nView Source\n]

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#    Incident ID  Incident Date   year       State  City Or County  \
# 0  Incident ID  Incident Date   year       State  City Or County
# 0            ]           None   None        None            None
# 1       739539    December 31   2016    Virginia    Newport News
# 2       739764    December 31   2016   Tennessee       Knoxville
# 3       738899    December 31   2016     Florida       Pensacola
#
#                 Address  Killed  Injured                      Operations
# 0               Address  Killed  Injured                      Operations
# 0                  None    None     None                            None
# 1          Vernon Place       0        1   View Incident\nView Source\n]
# 2   Highland View Drive       1        0   View Incident\nView Source\n]
# 3     3 Talladega Trail       1        1   View Incident\nView Source\n]

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 0 to 441
# Data columns (total 9 columns):
# Incident ID       443 non-null object
# Incident Date     426 non-null object
# year              426 non-null object
# State             426 non-null object
# City Or County    426 non-null object
# Address           426 non-null object
# Killed            426 non-null object
# Injured           426 non-null object
# Operations        426 non-null object
# dtypes: object(9)
# memory usage: 34.6+ KB
# (443, 9)

# %%
df6 = df5.dropna(axis=0, how='any')

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   Incident ID Incident Date   year          State City Or County  \
# 1      739539   December 31   2016       Virginia   Newport News
# 2      739764   December 31   2016      Tennessee      Knoxville
# 3      738899   December 31   2016        Florida      Pensacola
# 4      741817   December 31   2016   Pennsylvania      Lancaster
# 5      739284   December 31   2016       Maryland      Baltimore
#
#                          Address Killed Injured  \
# 1                   Vernon Place      0       1
# 2            Highland View Drive      1       0
# 3              3 Talladega Trail      1       1
# 4     100 block of Chesapeake St      0       0
# 5   4600 block of Reistertown Rd      0       1
#
#                        Operations
# 1   View Incident\nView Source\n]
# 2   View Incident\nView Source\n]
# 3   View Incident\nView Source\n]
# 4   View Incident\nView Source\n]
# 5   View Incident\nView Source\n]

# %%
df7['Operations'] = df7['Operations'].str.strip(']').str.strip('\n')
df7.head()
# Out:
#   Incident ID Incident Date   year          State City Or County  \
# 1      739539   December 31   2016       Virginia   Newport News
# 2      739764   December 31   2016      Tennessee      Knoxville
# 3      738899   December 31   2016        Florida      Pensacola
# 4      741817   December 31   2016   Pennsylvania      Lancaster
# 5      739284   December 31   2016       Maryland      Baltimore
#
#                          Address Killed Injured                   Operations
# 1                   Vernon Place      0       1   View Incident\nView Source
# 2            Highland View Drive      1       0   View Incident\nView Source
# 3              3 Talladega Trail      1       1   View Incident\nView Source
# 4     100 block of Chesapeake St      0       0   View Incident\nView Source
# 5   4600 block of Reistertown Rd      0       1   View Incident\nView Source

# %%
df7 = df7.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df7.to_csv("gunviolence2016_db.csv")

# %%
# Create engine using the `gunviolence_db.sqlite` database file
#engine = create_engine("sqlite:///../project2_team4/gunviolence_db.sqlite")

# %%
#df7.to_sql("gunviolence2019_db", con=engine)
